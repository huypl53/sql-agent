# %%
import csv
import pandas as pd
import pprint
import re
from typing import List, Dict, Any, Generator
import sqlglot
from typing import TypedDict, Any, Union, cast
from tqdm.notebook import tqdm

# %% [markdown]
# ## Helper functions

# %%
DIALECT = "mysql"

log_csv_file_path = '/mnt/Code/code/AI/agentic-AI/SQL-QA/logs/turn_log_benchmark.csv'

DELIMITER = (
        "\t"  # Using tab as delimiter which is less likely to appear in text content
    )

CANDIDATE_NAMES = [
    'direct_generation',
    'cot_generation',
    'dac_cot_genration',
    'query_plan_generation'
]

# %%
class LogRowEntry(TypedDict):
    created_date:Any
    user_question:Any
    linking_structured_result:Any
    filtered_schema_tables:Any
    direct_generation_prompt:Any
    generation_response:Any
    query_validation_prompt:Any
    query_validation_response:Any
    final_sql:Any
    cot_generation_prompt:Any
    dac_cot_genration_prompt:Any
    query_plan_generation_prompt:Any
    merger_prompt:Any
    merger_response:Any
    merger_result:Any
    sql_result:Any
    response_enhancement_prompt:Any
    response_enhancement_response:Any
    response_enhancement_result:Any
    query_fixing_prompt:Any
    query_fixing_response: Any      

class LlmRowEntry(TypedDict):
    question: Any
    ground_truth_sql: Any
    level: Any
    ground_truth_result: Any
    error: Any
    generated_sql_query: Any
    generated_query_result: Any
    generated_sql_error: Any
    generated_raw_result: Any
    llm_exact_match: Any
    llm_execution_match: Any

    candidate_generations: Any
    candidate_em: Any
    candidate_ex: Any
    candidate_least_correct: Any

# %%
def normalize_sql(sql: str, pretty=True) -> str:
    # TODO: sqlglot not supporting UTF-8
    """
    Normalize SQL queries by removing extra whitespace and converting to lowercase.
    """
    try:
        return sqlglot.transpile(
                    sql, write=DIALECT, pretty=pretty,
            )[0]

    except Exception as e:
        print(f"Error normalizing SQL: {e} at\nQuery: {sql}")
        # Fallback to a simple normalization if sqlglot fails
        return sql
    # return sqlglot.parse_one(sql).sql().lower().strip()
def is_exact_match(src_sql: str, tg_sql: str) -> bool:
    """
    Check if the query matches the answer exactly.
    """
    # return query.strip() == answer.strip()
    try:
        return normalize_sql(src_sql) == normalize_sql(tg_sql)
    except Exception as e:
        print(f"Error normalizing SQL: {e} at\nQuery: {src_sql}\nAnswer: {tg_sql}")
        return False

def normalize_answer(answer: str) -> str:   
    """
    Normalize the answer by removing extra whitespace and converting to lowercase.
    """
    return answer.strip().lower()
    
def is_execution_match(src_result: str, tg_result: str) -> bool:
    """
    Check if the query matches the answer after execution.
    """
    try:
        # Normalize both query and answer
        normalized_src_query = normalize_answer(src_result)
        normalized_tg_answer = normalize_answer(tg_result)
        
        # Compare normalized versions
        return normalized_src_query == normalized_tg_answer
    except Exception as e:
        print(f"Error normalizing execution result: {e} at\nQuery: {src_result}\nAnswer: {tg_result}")
        return False


regex = r"Câu lệnh SQL \d: ```sql([^`]*)```"

def parse_sql_candidates(regex=regex, merge_prompt='') -> List[str]:

    matches = re.finditer(regex, merge_prompt, re.MULTILINE | re.DOTALL)
    candidates = []
    for matchNum, match in enumerate(matches, start=1):
        
        # print ("Match {matchNum} was found at {start}-{end}: {match}".format(matchNum = matchNum, start = match.start(), end = match.end(), match = match.group()))
        
        for groupNum in range(0, len(match.groups())):
            groupNum = groupNum + 1
            
            # print ("Group {groupNum} found at {start}-{end}: {group}".format(groupNum = groupNum, start = match.start(groupNum), end = match.end(groupNum), group = match.group(groupNum)))
            # print(match.group(groupNum).strip())
            # print('-' * 20)
            sql = match.group(groupNum).strip()
            sql = normalize_sql(sql)
            candidates.append(sql)

    return candidates

# %%
def gen_get_row_sql_gen_candidates(
    csv_file_path: str, delimiter: str = DELIMITER
) -> Generator[LogRowEntry, None, None]:
    """
    Extract Rows from a CSV file and yield each row as a dictionary.
    Each row contains fields like:
    
    """
    with open(
        csv_file_path, "r", newline="", encoding="utf-8"
    ) as csvfile:
        reader = csv.DictReader(
            csvfile, delimiter=delimiter, quoting=csv.QUOTE_ALL
        )
        i = 0
        for row in reader:
            # i += 1
            # if i > 5: break
            # print(f'----------Row {i}---------')
            # pprint.pprint(row, indent=4, width=80)
            yield cast(LogRowEntry,row)

# %%
parse_sql_candidates(merge_prompt=merge_prompt)
# Out:
# ['SELECT\n  id,\n  branch_name,\n  branch_code,\n  description\nFROM branch\nWHERE\n  is_active = 1',
#  'SELECT\n  branch_name,\n  branch_code,\n  description\nFROM branch\nWHERE\n  is_active = 1',
#  'SELECT\n  branch_name,\n  branch_code,\n  description\nFROM branch\nWHERE\n  is_active = 1',
#  'SELECT\n  branch_name,\n  branch_code,\n  description\nFROM branch\nWHERE\n  is_active = 1']

# %%
row['merger_response']
# Out:
# " sql='SELECT branch_name, branch_code, description FROM branch WHERE is_active = 1;' explanation='The SQL query selects the branch_name, branch_code, and description from the branch table where the is_active flag is set to 1.'"

# %%
test_sql = ['SELECT\n  id,\n  branch_name,\n  branch_code,\n  description\nFROM branch\nWHERE\n  is_active = 1',
 'SELECT\n  branch_name,\n  branch_code,\n  description\nFROM branch\nWHERE\n  is_active = 1']

for sql in test_sql:
    print(f'Original SQL: \n```{sql}\n```')
    normalized_sql = normalize_sql(sql)
    print(f'Normalized SQL: \n```{normalized_sql}```')
    print(f'Is exact match: {is_exact_match(sql, normalized_sql)}')
    print('-' * 40)
# Out:
# Original SQL:
# ```SELECT
#   id,
#   branch_name,
#   branch_code,
#   description
# FROM branch
# WHERE
#   is_active = 1
# ```
# Normalized SQL:
# ```SELECT
#   id,
#   branch_name,
#   branch_code,
#   description
# FROM branch
# WHERE
#   is_active = 1```
# Is exact match: True
# ----------------------------------------
# Original SQL:
# ```SELECT
#   branch_name,
#   branch_code,
#   description
# FROM branch
# WHERE
#   is_active = 1
# ```
# Normalized SQL:
# ```SELECT
#   branch_name,
#   branch_code,
#   description
# FROM branch
# WHERE
#   is_active = 1```
# Is exact match: True
# ----------------------------------------

# %%
candidates_gen = gen_get_row_sql_gen_candidates(csv_file_path=log_csv_file_path, delimiter=DELIMITER)
# row = next(iter(candidates_gen))  # Skip the first row (header)
row = next(candidates_gen)  # Get the first row
print(row['user_question'])
# Out:
# Liệt kê tất cả các chi nhánh hiện đang hoạt động.

# %%
from langchain_community.utilities import SQLDatabase

conn = 'mysql+pymysql://root:yolo2chill@localhost:3306/gsv'
db =  SQLDatabase.from_uri(conn)

def get_sql_result(sql: str) -> Any:
    """
    Execute the SQL query and return the result.
    """
    # try:
    #     result = db.execute(sql)
    #     return result.fetchall()
    # except Exception as e:
    #     print(f"Error executing SQL: {e} at\nSQL: {sql}")
    #     return None
    result = db.run_no_throw(sql)
    return result

# %%
import sys

csv.field_size_limit(sys.maxsize)

csv_result_path = "/mnt/Code/code/AI/agentic-AI/SQL-QA/data/GSV/generated-data/gen_success_data_results_LLM_judge_updated.csv"

df = pd.read_csv(
    csv_result_path,
    encoding="utf-8",
    quoting=1,  # QUOTE_ALL mode
    escapechar="\\",
    on_bad_lines="warn",
)
df["candidate_generations"] = None
df["candidate_em"] = None
df["candidate_ex"] = None
df["candidate_least_correct"] = None
df["candidate_passes"] = None

candidates_gen = gen_get_row_sql_gen_candidates(
    csv_file_path=log_csv_file_path, delimiter=DELIMITER
)
pbar = tqdm(df.iterrows(), total=len(df), leave=False)
for idx, llm_row in pbar:
    # if idx > 5:
    #     break
    llm_row = cast(LlmRowEntry, llm_row)  # Ensure row is of type LlmRowEntry
    pbar.write(f"----------Row {idx}---------")
    pbar.write(f'Processing llm_row with question: {llm_row["question"]}')
    while True:
        try:
            candidate_row = next(candidates_gen)
        except StopIteration:
            pbar.write(f"No candidate row found for index {idx}")
            candidate_row = None
            break

        if candidate_row["user_question"] != llm_row["question"]:
            pbar.write(f'skip candidate row:\n{candidate_row["user_question"]}')
            continue  # Skip if the question matches the current row's question
        else:
            break
    if not candidate_row:
        break
    sql_candidates = parse_sql_candidates(merge_prompt=candidate_row["merger_prompt"])
    df.at[idx, "candidate_generations"] = sql_candidates
    em_candidates = [
        is_exact_match(c, llm_row["ground_truth_sql"]) for c in sql_candidates
    ]
    df.at[idx, "candidate_em"] = em_candidates
    ex_canddiates = [
        is_execution_match(get_sql_result(c), llm_row["ground_truth_result"])
        for c in sql_candidates
    ]
    df.at[idx, "candidate_ex"] = ex_canddiates
    df.at[idx, "candidate_least_correct"] = [
        c
        for c, em, ex in zip(sql_candidates, em_candidates, ex_canddiates)
        if (em) or (ex)
    ]
    df.at[idx, "candidate_passes"] = [
        CANDIDATE_NAMES[i]
        for i, (em, ex) in enumerate(zip(em_candidates, ex_canddiates))
        if (em) or (ex)
    ]
    # pbar.write(f'Row {idx} candidates: {row["candidate_generations"]}')

    # if int( idx ) > 5:
    #     break
    # pbar.write(llm_row)
    # pbar.write(llm_row['question'])
    # pbar.write(llm_row['candidate_generations'])
    # pbar.write(llm_row['candidate_em'])
    # pbar.write(llm_row['candidate_ex'])
    # pbar.write(llm_row['candidate_least_correct'])
    pass
pbar.close()
# Out:
#   0%|          | 0/289 [00:00<?, ?it/s]
# ----------Row 0---------
# Processing llm_row with question: Có bao nhiêu lịch hẹn được tạo trong tháng 3 năm 2025?
#
# ----------Row 1---------
# Processing llm_row with question: Liệt kê tất cả các chi nhánh hiện đang hoạt động.
#
# skip candidate row:
# Có bao nhiêu lịch hẹn được tạo trong tháng 3 năm 2025?
#
# ----------Row 2---------
# Processing llm_row with question: Có bao nhiêu khách hàng đặt lịch hẹn tại chi nhánh Hà Đông?
#
# skip candidate row:
# Có bao nhiêu lịch hẹn được tạo trong tháng 3 năm 2025?
#
# skip candidate row:
# Có bao nhiêu lịch hẹn được tạo trong tháng 3 năm 2025?
#
# skip candidate row:
# Liệt kê tất cả các chi nhánh hiện đang hoạt động.
#
# skip candidate row:
# Liệt kê tất cả các chi nhánh hiện đang hoạt động.
#
# ----------Row 3---------
# Processing llm_row with question: Liệt kê tất cả các lịch hẹn có trạng thái "Đã xác nhận" (appointment_status_id = 16).
#
# skip candidate row:
# Có bao nhiêu khách hàng đặt lịch hẹn tại chi nhánh Hà Đông?
#
# skip candidate row:
# Có bao nhiêu lịch hẹn được tạo trong tháng 3 năm 2025?
#
# skip candidate row:
# Có bao nhiêu lịch hẹn được tạo trong tháng 3 năm 2025?
#
# skip candidate row:
# Liệt kê tất cả các chi nhánh hiện đang hoạt động.
#
# skip candidate row:
# Liệt kê tất cả các chi nhánh hiện đang hoạt động.
#
# skip candidate row:
# Có bao nhiêu khách hàng đặt lịch hẹn tại chi nhánh Hà Đông?
#
# skip candidate row:
# Có bao nhiêu khách hàng đặt lịch hẹn tại chi nhánh Hà Đông?
#
# Error normalizing SQL: Invalid expression / Unexpected token. Line 2, Col: 27.
#   SELECT
#   a.appointment_code AS `Mã cuộc hẹn`,
#   a.full_name AS `Tên người hẹn`,
#   a.mobile_phone AS `Số điện thoại`,
#   rc.value AS `Tr at
# Query: SELECT
#   a.appointment_code AS `Mã cuộc hẹn`,
#   a.full_name AS `Tên người hẹn`,
#   a.mobile_phone AS `Số điện thoại`,
#   rc.value AS `Trạng thái cuộc hẹn`,
#   a.appointment_time AS `Thời gian cuộc hẹn`,
#   a.content AS `Nội dung cuộc hẹn`,
#   a.remarks AS `Ghi chú`,
#   a.estimate_time AS `Thời gian ước tính (phút)`
# FROM appointment AS a
# JOIN reference_code AS rc
#   ON a.appointment_status_id = rc.id
# WHERE
#   a.appointment_status_id = 16
# Error normalizing SQL: Invalid expression / Unexpected token. Line 2, Col: 27.
#   SELECT
#   a.appointment_code AS `Mã cuộc hẹn`,
#   a.full_name AS `Tên người hẹn`,
#   a.mobile_phone AS `Số điện thoại`,
#   a.appointment_t at
# Query: SELECT
#   a.appointment_code AS `Mã cuộc hẹn`,
#   a.full_name AS `Tên người hẹn`,
#   a.mobile_phone AS `Số điện thoại`,
#   a.appointment_time AS `Thời gian hẹn`,
#   rc.value AS `Trạng thái cuộc hẹn`
# FROM appointment AS a
# JOIN reference_code AS rc
#   ON a.appointment_status_id = rc.id
# WHERE
#   a.appointment_status_id = 16
# ----------Row 4---------
# Processing llm_row with question: Có bao nhiêu lịch hẹn bị hủy trong tháng 3 năm 2025?
#
# skip candidate row:
# Liệt kê tất cả các lịch hẹn có trạng thái "Đã xác nhận" (appointment_status_id = 16).
#
# Error normalizing SQL: Invalid expression / Unexpected token. Line 2, Col: 18.
#   SELECT
#   COUNT(id) AS `Số lượng lịch hẹn bị hủy trong tháng 3 năm 2025`
# FROM appointment
# WHERE
#   EXTRACT(YEAR_MONTH FROM canc at
# Query: SELECT
#   COUNT(id) AS `Số lượng lịch hẹn bị hủy trong tháng 3 năm 2025`
# FROM appointment
# WHERE
#   EXTRACT(YEAR_MONTH FROM cancelled_on) = 202503
# ----------Row 5---------
# Processing llm_row with question: Liệt kê các dịch vụ được sử dụng trong lịch hẹn ngày 12/03/2025.
#
# skip candidate row:
# Có bao nhiêu lịch hẹn bị hủy trong tháng 3 năm 2025?
#
# ----------Row 6---------
# Processing llm_row with question: Tìm tất cả các lịch hẹn của bệnh nhân có số điện thoại 0989149111.
#
# skip candidate row:
# Liệt kê các dịch vụ được sử dụng trong lịch hẹn ngày 12/03/2025.
#
# Error normalizing SQL: Invalid expression / Unexpected token. Line 2, Col: 27.
#   SELECT
#   a.appointment_code AS `Mã cuộc hẹn`,
#   a.full_name AS `Tên người hẹn`,
#   a.appointment_time AS `Thời gian cuộc hẹn`,
#   a.cont at
# Query: SELECT
#   a.appointment_code AS `Mã cuộc hẹn`,
#   a.full_name AS `Tên người hẹn`,
#   a.appointment_time AS `Thời gian cuộc hẹn`,
#   a.content AS `Nội dung cuộc hẹn`,
#   a.remarks AS `Ghi chú`
# FROM appointment AS a
# JOIN patient AS p
#   ON a.patient_id = p.id
# WHERE
#   p.mobile_phone = '0989149111'
# Error normalizing SQL: Invalid expression / Unexpected token. Line 2, Col: 27.
#   SELECT
#   a.appointment_code AS `Mã cuộc hẹn`,
#   p.full_name AS `Tên bệnh nhân`,
#   a.appointment_time AS `Thời gian cuộc hẹn`,
#   a.cont at
# Query: SELECT
#   a.appointment_code AS `Mã cuộc hẹn`,
#   p.full_name AS `Tên bệnh nhân`,
#   a.appointment_time AS `Thời gian cuộc hẹn`,
#   a.content AS `Nội dung cuộc hẹn`,
#   a.remarks AS `Ghi chú`,
#   a.performer_name AS `Người thực hiện`,
#   a.performer_phone AS `SĐT người thực hiện`
# FROM appointment AS a
# JOIN patient AS p
#   ON a.patient_id = p.id
# WHERE
#   p.mobile_phone = `0989149111`
# Error normalizing SQL: Invalid expression / Unexpected token. Line 2, Col: 27.
#   SELECT
#   a.appointment_code AS `Mã cuộc hẹn`,
#   p.full_name AS `Tên bệnh nhân`,
#   a.appointment_time AS `Thời gian hẹn`,
#   a.content A at
# Query: SELECT
#   a.appointment_code AS `Mã cuộc hẹn`,
#   p.full_name AS `Tên bệnh nhân`,
#   a.appointment_time AS `Thời gian hẹn`,
#   a.content AS `Nội dung cuộc hẹn`,
#   a.remarks AS `Ghi chú`,
#   a.estimate_time AS `Thời gian ước tính (phút)`
# FROM patient AS p
# JOIN appointment AS a
#   ON p.id = a.patient_id
# WHERE
#   p.mobile_phone = `0989149111`
# ----------Row 7---------
# Processing llm_row with question: Có bao nhiêu khách hàng sinh nhật trong tháng 3?
#
# skip candidate row:
# Tìm tất cả các lịch hẹn của bệnh nhân có số điện thoại 0989149111.
#
# ----------Row 8---------
# Processing llm_row with question: Liệt kê các khiếu nại được tạo trong tháng 3 năm 2025.
#
# skip candidate row:
# Có bao nhiêu khách hàng sinh nhật trong tháng 3?
#
# Error normalizing SQL: Invalid expression / Unexpected token. Line 2, Col: 23.
#   SELECT
#   complaint_code AS `Mã khiếu nại`,
#   patient_name AS `Tên bệnh nhân`,
#   service_name AS `Tên dịch vụ`,
#   content_complaint at
# Query: SELECT
#   complaint_code AS `Mã khiếu nại`,
#   patient_name AS `Tên bệnh nhân`,
#   service_name AS `Tên dịch vụ`,
#   content_complaint AS `Nội dung khiếu nại`,
#   created_on AS `Ngày tạo`
# FROM complaint
# WHERE
#   MONTH(created_on) = 3 AND YEAR(created_on) = 2025
# ----------Row 9---------
# Processing llm_row with question: Tìm tổng số lượng lô hàng nhập kho trong tháng 3 năm 2025.
#
# skip candidate row:
# Liệt kê các khiếu nại được tạo trong tháng 3 năm 2025.
#
# ----------Row 10---------
# Processing llm_row with question: Liệt kê các phòng ban hiện có trong hệ thống.
#
# skip candidate row:
# Tìm tổng số lượng lô hàng nhập kho trong tháng 3 năm 2025.
#
# ----------Row 11---------
# Processing llm_row with question: Tìm tên bệnh nhân có lịch hẹn vào ngày 13/03/2025.
#
# skip candidate row:
# Liệt kê các phòng ban hiện có trong hệ thống.
#
# ----------Row 12---------
# Processing llm_row with question: Có bao nhiêu nhân viên thuộc phòng ban GSV Technology?
#
# skip candidate row:
# Tìm tên bệnh nhân có lịch hẹn vào ngày 13/03/2025.
#
# ----------Row 13---------
# Processing llm_row with question: Liệt kê các lịch hẹn có thời gian ước tính là 30 phút.
#
# skip candidate row:
# Có bao nhiêu nhân viên thuộc phòng ban GSV Technology?
#
# Error normalizing SQL: Invalid expression / Unexpected token. Line 2, Col: 25.
#   SELECT
#   appointment_code AS `Mã cuộc hẹn`,
#   full_name AS `Tên người hẹn`,
#   mobile_phone AS `Số điện thoại`,
#   appointment_time AS at
# Query: SELECT
#   appointment_code AS `Mã cuộc hẹn`,
#   full_name AS `Tên người hẹn`,
#   mobile_phone AS `Số điện thoại`,
#   appointment_time AS `Thời gian cuộc hẹn`,
#   estimate_time AS `Thời gian ước tính (phút)`,
#   performer_name AS `Người thực hiện`,
#   content AS `Nội dung`,
#   remarks AS `Ghi chú`
# FROM appointment
# WHERE
#   estimate_time = 30
# ----------Row 14---------
# Processing llm_row with question: Tìm mã lịch hẹn của bệnh nhân có tên "Cường nguyễn".
#
# skip candidate row:
# Liệt kê các lịch hẹn có thời gian ước tính là 30 phút.
#
# Error normalizing SQL: Invalid expression / Unexpected token. Line 5, Col: 20.
#   SELECT
#   appointment_code
# FROM appointment
# WHERE
#   full_name = `Cường nguyễn` at
# Query: SELECT
#   appointment_code
# FROM appointment
# WHERE
#   full_name = `Cường nguyễn`
# ----------Row 15---------
# Processing llm_row with question: Có bao nhiêu khiếu nại có trạng thái "Đang xử lý" (complaint_status_id = 33)?
#
# skip candidate row:
# Tìm mã lịch hẹn của bệnh nhân có tên "Cường nguyễn".
#
# ----------Row 16---------
# Processing llm_row with question: Liệt kê các dịch vụ được sử dụng trong lịch hẹn có mã AP89461741787064.
#
# skip candidate row:
# Có bao nhiêu khiếu nại có trạng thái "Đang xử lý" (complaint_status_id = 33)?
#
# Error normalizing SQL: Invalid expression / Unexpected token. Line 2, Col: 24.
#   SELECT
#   s.service_name AS `Tên dịch vụ`
# FROM appointment AS a
# INNER JOIN appointment_service AS aps
#   ON a.id = aps.appointment_id at
# Query: SELECT
#   s.service_name AS `Tên dịch vụ`
# FROM appointment AS a
# INNER JOIN appointment_service AS aps
#   ON a.id = aps.appointment_id
# INNER JOIN service AS s
#   ON aps.service_id = s.id
# WHERE
#   a.appointment_code = `AP89461741787064`
# Error normalizing SQL: Invalid expression / Unexpected token. Line 9, Col: 40.
#   .id = aps.appointment_id
# JOIN service AS s
#   ON aps.service_id = s.id
# WHERE
#   a.appointment_code = `AP89461741787064` at
# Query: SELECT
#   s.service_name
# FROM appointment AS a
# JOIN appointment_service AS aps
#   ON a.id = aps.appointment_id
# JOIN service AS s
#   ON aps.service_id = s.id
# WHERE
#   a.appointment_code = `AP89461741787064`
# ----------Row 17---------
# Processing llm_row with question: Tìm tất cả các lô hàng hết hạn trước ngày 01/01/2026.
#
# skip candidate row:
# Liệt kê các dịch vụ được sử dụng trong lịch hẹn có mã AP89461741787064.
#
# ----------Row 18---------
# Processing llm_row with question: Có bao nhiêu lịch hẹn được lên lịch bởi nhân viên có id = 1?
#
# skip candidate row:
# Tìm tất cả các lô hàng hết hạn trước ngày 01/01/2026.
#
# ----------Row 19---------
# Processing llm_row with question: Liệt kê các lịch hẹn có trạng thái lịch sử thay đổi trong tháng 3 năm 2025.
#
# skip candidate row:
# Có bao nhiêu lịch hẹn được lên lịch bởi nhân viên có id = 1?
#
# Error normalizing SQL: Invalid expression / Unexpected token. Line 2, Col: 27.
#   SELECT
#   a.appointment_code AS `Mã cuộc hẹn`,
#   a.full_name AS `Tên người hẹn`,
#   a.appointment_time AS `Thời gian cuộc hẹn`,
#   ah.sta at
# Query: SELECT
#   a.appointment_code AS `Mã cuộc hẹn`,
#   a.full_name AS `Tên người hẹn`,
#   a.appointment_time AS `Thời gian cuộc hẹn`,
#   ah.status_time AS `Thời gian thay đổi trạng thái`,
#   rc.value AS `Trạng thái cuộc hẹn`
# FROM appointment_history AS ah
# JOIN appointment AS a
#   ON ah.appointment_id = a.id
# JOIN reference_code AS rc
#   ON ah.appointment_status_id = rc.id
# WHERE
#   ah.status_time >= '2025-03-01' AND ah.status_time < '2025-04-01'
# Error normalizing SQL: Invalid expression / Unexpected token. Line 2, Col: 27.
#   SELECT
#   a.appointment_code AS `Mã cuộc hẹn`,
#   a.full_name AS `Tên người hẹn`,
#   a.mobile_phone AS `Số điện thoại`,
#   ah.status_time  at
# Query: SELECT
#   a.appointment_code AS `Mã cuộc hẹn`,
#   a.full_name AS `Tên người hẹn`,
#   a.mobile_phone AS `Số điện thoại`,
#   ah.status_time AS `Thời gian thay đổi trạng thái`,
#   rc.value AS `Trạng thái cuộc hẹn`,
#   ah.reason AS `Lý do thay đổi`
# FROM appointment_history AS ah
# JOIN appointment AS a
#   ON ah.appointment_id = a.id
# JOIN reference_code AS rc
#   ON ah.appointment_status_id = rc.id
# WHERE
#   MONTH(ah.status_time) = 3 AND YEAR(ah.status_time) = 2025
# ----------Row 20---------
# Processing llm_row with question: Tìm tên bệnh nhân và số điện thoại của các lịch hẹn vào ngày 12/03/2025.
#
# skip candidate row:
# Liệt kê các lịch hẹn có trạng thái lịch sử thay đổi trong tháng 3 năm 2025.
#
# ----------Row 21---------
# Processing llm_row with question: Có bao nhiêu dịch vụ được sử dụng trong tất cả các lịch hẹn?
#
# skip candidate row:
# Tìm tên bệnh nhân và số điện thoại của các lịch hẹn vào ngày 12/03/2025.
#
# ----------Row 22---------
# Processing llm_row with question: Liệt kê các chi nhánh có mã chi nhánh bắt đầu bằng "GSV".
#
# skip candidate row:
# Có bao nhiêu dịch vụ được sử dụng trong tất cả các lịch hẹn?
#
# ----------Row 23---------
# Processing llm_row with question: Tìm tất cả các khiếu nại liên quan đến dịch vụ "Triệt lông ấn đường".
#
# skip candidate row:
# Liệt kê các chi nhánh có mã chi nhánh bắt đầu bằng "GSV".
#
# Error normalizing SQL: Invalid expression / Unexpected token. Line 2, Col: 23.
#   SELECT
#   complaint_code AS `Mã khiếu nại`,
#   patient_name AS `Tên bệnh nhân`,
#   content_complaint AS `Nội dung khiếu nại`,
#   creat at
# Query: SELECT
#   complaint_code AS `Mã khiếu nại`,
#   patient_name AS `Tên bệnh nhân`,
#   content_complaint AS `Nội dung khiếu nại`,
#   created_on AS `Thời gian tạo`,
#   complaint_status_id AS `Trạng thái`,
#   complaint_type_id AS `Loại khiếu nại`
# FROM complaint
# WHERE
#   service_name = `Triệt lông ấn đường`
# Error normalizing SQL: Invalid expression / Unexpected token. Line 2, Col: 25.
#   SELECT
#   c.complaint_code AS `Mã khiếu nại`,
#   c.patient_name AS `Tên bệnh nhân`,
#   c.service_name AS `Tên dịch vụ`,
#   c.content_com at
# Query: SELECT
#   c.complaint_code AS `Mã khiếu nại`,
#   c.patient_name AS `Tên bệnh nhân`,
#   c.service_name AS `Tên dịch vụ`,
#   c.content_complaint AS `Nội dung khiếu nại`
# FROM complaint AS c
# WHERE
#   c.service_name = `Triệt lông ấn đường`
# ----------Row 24---------
# Processing llm_row with question: Có bao nhiêu lịch hẹn được tạo bởi người dùng có tên "Admin"?
#
# skip candidate row:
# Tìm tất cả các khiếu nại liên quan đến dịch vụ "Triệt lông ấn đường".
#
# Error normalizing SQL: Invalid expression / Unexpected token. Line 5, Col: 18.
#   SELECT
#   COUNT(*) AS total_appointments
# FROM appointment
# WHERE
#   creator = `Admin` at
# Query: SELECT
#   COUNT(*) AS total_appointments
# FROM appointment
# WHERE
#   creator = `Admin`
# ----------Row 25---------
# Processing llm_row with question: Liệt kê các lô hàng có số lượng còn lại lớn hơn 0.
#
# skip candidate row:
# Có bao nhiêu lịch hẹn được tạo bởi người dùng có tên "Admin"?
#
# ----------Row 26---------
# Processing llm_row with question: Tìm tên bệnh nhân có lịch hẹn với bác sĩ có id = 41.
#
# skip candidate row:
# Liệt kê các lô hàng có số lượng còn lại lớn hơn 0.
#
# ----------Row 27---------
# Processing llm_row with question: Có bao nhiêu lịch hẹn có thời gian thực hiện trong khoảng từ 12/03/2025 đến 13/03/2025?
#
# skip candidate row:
# Tìm tên bệnh nhân có lịch hẹn với bác sĩ có id = 41.
#
# Error normalizing SQL: Invalid expression / Unexpected token. Line 5, Col: 42.
#   T
#   COUNT(id) AS total_appointments
# FROM appointment
# WHERE
#   appointment_time BETWEEN `2025-03-12 00:00:00` AND `2025-03-13 23:59:59` at
# Query: SELECT
#   COUNT(id) AS total_appointments
# FROM appointment
# WHERE
#   appointment_time BETWEEN `2025-03-12 00:00:00` AND `2025-03-13 23:59:59`
# ----------Row 28---------
# Processing llm_row with question: Liệt kê các lịch hẹn có kỹ thuật viên thực hiện (technican_id không null).
#
# skip candidate row:
# Có bao nhiêu lịch hẹn có thời gian thực hiện trong khoảng từ 12/03/2025 đến 13/03/2025?
#
# ----------Row 29---------
# Processing llm_row with question: Tìm tất cả các khiếu nại được xử lý bởi nhân viên có id = 1.
#
# skip candidate row:
# Liệt kê các lịch hẹn có kỹ thuật viên thực hiện (technican_id không null).
#
# Error normalizing SQL: Invalid expression / Unexpected token. Line 2, Col: 23.
#   SELECT
#   complaint_code AS `Mã khiếu nại`,
#   patient_name AS `Tên bệnh nhân`,
#   service_name AS `Tên dịch vụ`,
#   content_complaint at
# Query: SELECT
#   complaint_code AS `Mã khiếu nại`,
#   patient_name AS `Tên bệnh nhân`,
#   service_name AS `Tên dịch vụ`,
#   content_complaint AS `Nội dung khiếu nại`
# FROM complaint
# WHERE
#   telesale_id = 1 OR doctor_id = 1 OR technican_id = 1
# ----------Row 30---------
# Processing llm_row with question: Có bao nhiêu khách hàng có lịch hẹn tại chi nhánh Từ Liêm?
#
# skip candidate row:
# Tìm tất cả các khiếu nại được xử lý bởi nhân viên có id = 1.
#
# ----------Row 31---------
# Processing llm_row with question: Liệt kê các lịch hẹn có nội dung (content) không rỗng.
#
# skip candidate row:
# Có bao nhiêu khách hàng có lịch hẹn tại chi nhánh Từ Liêm?
#
# ----------Row 32---------
# Processing llm_row with question: Tìm tên bệnh nhân và mã lịch hẹn của các lịch hẹn vào ngày 12/03/2025.
#
# skip candidate row:
# Liệt kê các lịch hẹn có nội dung (content) không rỗng.
#
# ----------Row 33---------
# Processing llm_row with question: Có bao nhiêu lô hàng được nhập từ nhà cung cấp (supplier_id không null)?
#
# skip candidate row:
# Tìm tên bệnh nhân và mã lịch hẹn của các lịch hẹn vào ngày 12/03/2025.
#
# ----------Row 34---------
# Processing llm_row with question: Liệt kê các lịch hẹn có thời gian ước tính lớn hơn 30 phút.
#
# skip candidate row:
# Có bao nhiêu lô hàng được nhập từ nhà cung cấp (supplier_id không null)?
#
# Error normalizing SQL: Invalid expression / Unexpected token. Line 2, Col: 25.
#   SELECT
#   appointment_code AS `Mã cuộc hẹn`,
#   full_name AS `Tên người hẹn`,
#   mobile_phone AS `Số điện thoại`,
#   appointment_time AS at
# Query: SELECT
#   appointment_code AS `Mã cuộc hẹn`,
#   full_name AS `Tên người hẹn`,
#   mobile_phone AS `Số điện thoại`,
#   appointment_time AS `Thời gian cuộc hẹn`,
#   estimate_time AS `Thời gian ước tính (phút)`,
#   content AS `Nội dung cuộc hẹn`,
#   remarks AS `Ghi chú`
# FROM appointment
# WHERE
#   estimate_time > 30
# ----------Row 35---------
# Processing llm_row with question: Tìm tất cả các lịch hẹn được tạo trước ngày 13/03/2025.
#
# skip candidate row:
# Liệt kê các lịch hẹn có thời gian ước tính lớn hơn 30 phút.
#
# ----------Row 36---------
# Processing llm_row with question: Có bao nhiêu khiếu nại liên quan đến bác sĩ có id = 41?
#
# skip candidate row:
# Tìm tất cả các lịch hẹn được tạo trước ngày 13/03/2025.
#
# ----------Row 37---------
# Processing llm_row with question: Liệt kê các phòng ban có trưởng phòng là "Mrs Phuong".
#
# skip candidate row:
# Có bao nhiêu khiếu nại liên quan đến bác sĩ có id = 41?
#
# Error normalizing SQL: Invalid expression / Unexpected token. Line 5, Col: 24.
#   SELECT
#   department_name
# FROM department
# WHERE
#   department_head = `Mrs Phuong` at
# Query: SELECT
#   department_name
# FROM department
# WHERE
#   department_head = `Mrs Phuong`
# Error normalizing SQL: Invalid expression / Unexpected token. Line 5, Col: 24.
#   SELECT
#   department_name
# FROM department
# WHERE
#   department_head = `Mrs Phuong` at
# Query: SELECT
#   department_name
# FROM department
# WHERE
#   department_head = `Mrs Phuong`
# Error normalizing SQL: Invalid expression / Unexpected token. Line 5, Col: 24.
#   SELECT
#   department_name
# FROM department
# WHERE
#   department_head = `Mrs Phuong` at
# Query: SELECT
#   department_name
# FROM department
# WHERE
#   department_head = `Mrs Phuong`
# ----------Row 38---------
# Processing llm_row with question: Tìm tất cả các lịch hẹn của bệnh nhân có id = 8946.
#
# skip candidate row:
# Liệt kê các phòng ban có trưởng phòng là "Mrs Phuong".
#
# Error normalizing SQL: Invalid expression / Unexpected token. Line 2, Col: 27.
#   SELECT
#   a.appointment_code AS `Mã cuộc hẹn`,
#   a.full_name AS `Tên người hẹn`,
#   a.mobile_phone AS `Số điện thoại`,
#   a.appointment_t at
# Query: SELECT
#   a.appointment_code AS `Mã cuộc hẹn`,
#   a.full_name AS `Tên người hẹn`,
#   a.mobile_phone AS `Số điện thoại`,
#   a.appointment_time AS `Thời gian cuộc hẹn`,
#   a.content AS `Nội dung cuộc hẹn`,
#   a.remarks AS `Ghi chú`,
#   a.performer_name AS `Người thực hiện`,
#   a.performer_phone AS `SĐT người thực hiện`,
#   a.appointment_type_id AS `Loại cuộc hẹn`,
#   a.appointment_status_id AS `Trạng thái cuộc hẹn`
# FROM appointment AS a
# WHERE
#   a.patient_id = 8946
# ----------Row 39---------
# Processing llm_row with question: Có bao nhiêu lịch hẹn có trạng thái lịch sử là "Đã xác nhận" (appointment_status_id = 16)?
#
# skip candidate row:
# Tìm tất cả các lịch hẹn của bệnh nhân có id = 8946.
#
# ----------Row 40---------
# Processing llm_row with question: Liệt kê các dịch vụ được sử dụng trong lịch hẹn có id = 2.
#
# skip candidate row:
# Có bao nhiêu lịch hẹn có trạng thái lịch sử là "Đã xác nhận" (appointment_status_id = 16)?
#
# ----------Row 41---------
# Processing llm_row with question: Tìm tên bệnh nhân có khiếu nại với mã KN89461741788415.
#
# skip candidate row:
# Liệt kê các dịch vụ được sử dụng trong lịch hẹn có id = 2.
#
# ----------Row 42---------
# Processing llm_row with question: Có bao nhiêu lịch hẹn được lên lịch bởi nhân viên có tên "Admin"?
#
# skip candidate row:
# Tìm tên bệnh nhân có khiếu nại với mã KN89461741788415.
#
# Error normalizing SQL: Invalid expression / Unexpected token. Line 2, Col: 20.
#   SELECT
#   COUNT(A.id) AS `Số lượng lịch hẹn được lên lịch bởi Admin`
# FROM employee AS E
# JOIN appointment AS A
#   ON E.id = A.sche at
# Query: SELECT
#   COUNT(A.id) AS `Số lượng lịch hẹn được lên lịch bởi Admin`
# FROM employee AS E
# JOIN appointment AS A
#   ON E.id = A.schedule_by
# WHERE
#   E.first_name = 'Admin'
# ----------Row 43---------
# Processing llm_row with question: Liệt kê các lô hàng có trạng thái hết hạn (expiry_status_id = 123).
#
# skip candidate row:
# Có bao nhiêu lịch hẹn được lên lịch bởi nhân viên có tên "Admin"?
#
# ----------Row 44---------
# Processing llm_row with question: Tìm tất cả các lịch hẹn có thời gian thực hiện vào buổi chiều ngày 12/03/2025.
#
# skip candidate row:
# Liệt kê các lô hàng có trạng thái hết hạn (expiry_status_id = 123).
#
# ----------Row 45---------
# Processing llm_row with question: Có bao nhiêu khách hàng có lịch hẹn với kỹ thuật viên có id = 46?
#
# skip candidate row:
# Tìm tất cả các lịch hẹn có thời gian thực hiện vào buổi chiều ngày 12/03/2025.
#
# Error normalizing SQL: Invalid expression / Unexpected token. Line 2, Col: 35.
#   SELECT
#   COUNT(DISTINCT patient_id) AS `Số lượng khách hàng`
# FROM appointment
# WHERE
#   technican_id = 46 at
# Query: SELECT
#   COUNT(DISTINCT patient_id) AS `Số lượng khách hàng`
# FROM appointment
# WHERE
#   technican_id = 46
# ----------Row 46---------
# Processing llm_row with question: Liệt kê các khiếu nại có trạng thái "Đã giải quyết" (complaint_status_id = 35).
#
# skip candidate row:
# Có bao nhiêu khách hàng có lịch hẹn với kỹ thuật viên có id = 46?
#
# Error normalizing SQL: Invalid expression / Unexpected token. Line 2, Col: 25.
#   SELECT
#   c.complaint_code AS `Mã khiếu nại`,
#   c.patient_name AS `Tên bệnh nhân`,
#   c.service_name AS `Tên dịch vụ`,
#   c.content_com at
# Query: SELECT
#   c.complaint_code AS `Mã khiếu nại`,
#   c.patient_name AS `Tên bệnh nhân`,
#   c.service_name AS `Tên dịch vụ`,
#   c.content_complaint AS `Nội dung khiếu nại`,
#   rc.value AS `Trạng thái khiếu nại`
# FROM complaint AS c
# JOIN reference_code AS rc
#   ON c.complaint_status_id = rc.id
# WHERE
#   c.complaint_status_id = 35
# Error normalizing SQL: Invalid expression / Unexpected token. Line 2, Col: 25.
#   SELECT
#   c.complaint_code AS `Mã khiếu nại`,
#   c.patient_name AS `Tên bệnh nhân`,
#   c.service_name AS `Tên dịch vụ`,
#   c.treatment_d at
# Query: SELECT
#   c.complaint_code AS `Mã khiếu nại`,
#   c.patient_name AS `Tên bệnh nhân`,
#   c.service_name AS `Tên dịch vụ`,
#   c.treatment_detail_name AS `Chi tiết điều trị`,
#   c.content_complaint AS `Nội dung khiếu nại`
# FROM complaint AS c
# WHERE
#   c.complaint_status_id = 35
# ----------Row 47---------
# Processing llm_row with question: Tìm tên bệnh nhân và số điện thoại của các lịch hẹn có trạng thái "Đã xác nhận".
#
# skip candidate row:
# Liệt kê các khiếu nại có trạng thái "Đã giải quyết" (complaint_status_id = 35).
#
# ----------Row 48---------
# Processing llm_row with question: Có bao nhiêu lịch hẹn có bác sĩ thực hiện (doctor_id không null)?
#
# skip candidate row:
# Tìm tên bệnh nhân và số điện thoại của các lịch hẹn có trạng thái "Đã xác nhận".
#
# ----------Row 49---------
# Processing llm_row with question: Liệt kê các lịch hẹn có thời gian thực hiện trong tháng 3 năm 2025.
#
# skip candidate row:
# Có bao nhiêu lịch hẹn có bác sĩ thực hiện (doctor_id không null)?
#
# ----------Row 50---------
# Processing llm_row with question: Tìm tổng doanh thu từ các hóa đơn dịch vụ tại chi nhánh Hà Đông vào ngày 12/03/2025.
#
# skip candidate row:
# Liệt kê các lịch hẹn có thời gian thực hiện trong tháng 3 năm 2025.
#
# Error normalizing SQL: Invalid expression / Unexpected token. Line 2, Col: 31.
#   SELECT
#   SUM(si.total_amount) AS `Tổng doanh thu`
# FROM service_invoice AS si
# JOIN branch AS b
#   ON si.branch_id = b.id
# WHERE
#   b.branch_na at
# Query: SELECT
#   SUM(si.total_amount) AS `Tổng doanh thu`
# FROM service_invoice AS si
# JOIN branch AS b
#   ON si.branch_id = b.id
# WHERE
#   b.branch_name = 'Chi nhánh Hà Đông' AND DATE(si.paid_date) = '2025-03-12'
# ----------Row 51---------
# Processing llm_row with question: Tìm danh sách bệnh nhân có lịch hẹn tại chi nhánh Cầu Giấy và đã thanh toán hóa đơn dịch vụ.
#
# skip candidate row:
# Tìm tổng doanh thu từ các hóa đơn dịch vụ tại chi nhánh Hà Đông vào ngày 12/03/2025.
#
# Error normalizing SQL: Invalid expression / Unexpected token. Line 2, Col: 21.
#   SELECT DISTINCT
#   p.full_name AS `Tên bệnh nhân`,
#   p.patient_code AS `Mã bệnh nhân`,
#   p.mobile_phone AS `Số điện thoại`,
#   b.branch_nam at
# Query: SELECT DISTINCT
#   p.full_name AS `Tên bệnh nhân`,
#   p.patient_code AS `Mã bệnh nhân`,
#   p.mobile_phone AS `Số điện thoại`,
#   b.branch_name AS `Chi nhánh`
# FROM patient AS p
# JOIN appointment AS a
#   ON p.id = a.patient_id
# JOIN branch AS b
#   ON a.branch_id = b.id
# JOIN service_invoice AS si
#   ON p.id = si.patient_id
# WHERE
#   b.branch_name = 'Chi nhánh Cầu Giấy' AND si.paid_amount > 0
# ----------Row 52---------
# Processing llm_row with question: Tìm tổng số tiền chưa thanh toán (công nợ) của các hóa đơn dịch vụ tại chi nhánh Từ Liêm vào ngày 12/03/2025.
#
# skip candidate row:
# Tìm danh sách bệnh nhân có lịch hẹn tại chi nhánh Cầu Giấy và đã thanh toán hóa đơn dịch vụ.
#
# ----------Row 53---------
# Processing llm_row with question: Tìm tổng số lượng dịch vụ được sử dụng trong các lịch hẹn tại chi nhánh Hà Đông trong tháng 3 năm 2025.
#
# skip candidate row:
# Tìm tổng số tiền chưa thanh toán (công nợ) của các hóa đơn dịch vụ tại chi nhánh Từ Liêm vào ngày 12/03/2025.
#
# Error normalizing SQL: Invalid expression / Unexpected token. Line 2, Col: 27.
#   SELECT
#   SUM(T1.quantity) AS `Tổng số lượng dịch vụ`
# FROM service AS T1
# INNER JOIN appointment_service AS T2
#   ON T1.id = T2.service_i at
# Query: SELECT
#   SUM(T1.quantity) AS `Tổng số lượng dịch vụ`
# FROM service AS T1
# INNER JOIN appointment_service AS T2
#   ON T1.id = T2.service_id
# INNER JOIN appointment AS T3
#   ON T2.appointment_id = T3.id
# INNER JOIN branch AS T4
#   ON T3.branch_id = T4.id
# WHERE
#   T4.branch_name = 'Chi nhánh Hà Đông'
#   AND T2.appointment_month = 3
#   AND T2.appointment_year = 2025
# ----------Row 54---------
# Processing llm_row with question: Tìm bệnh nhân có nhiều lịch hẹn nhất trong tháng 3 năm 2025.
#
# skip candidate row:
# Tìm tổng số lượng dịch vụ được sử dụng trong các lịch hẹn tại chi nhánh Hà Đông trong tháng 3 năm 2025.
#
# Error normalizing SQL: Invalid expression / Unexpected token. Line 9, Col: 35.
#   patient AS p
# JOIN appointment AS a
#   ON p.id = a.patient_id
# WHERE
#   YEAR(a.appointment_time) = `2025` AND MONTH(a.appointment_time) = `03`
# GROUP BY
#   p.id,
#   p.full_name
# ORDER BY
#   appointment_count DE at
# Query: SELECT
#   p.id AS patient_id,
#   p.full_name,
#   COUNT(a.id) AS appointment_count
# FROM patient AS p
# JOIN appointment AS a
#   ON p.id = a.patient_id
# WHERE
#   YEAR(a.appointment_time) = `2025` AND MONTH(a.appointment_time) = `03`
# GROUP BY
#   p.id,
#   p.full_name
# ORDER BY
#   appointment_count DESC
# LIMIT 1
# Error normalizing SQL: Invalid expression / Unexpected token. Line 9, Col: 60.
#   tment AS a
#   ON p.id = a.patient_id
# WHERE
#   a.appointment_time BETWEEN `2025-03-01` AND `2025-03-31 23:59:59`
# GROUP BY
#   p.id
# ORDER BY
#   appointment_count DESC
# LIMIT 1 at
# Query: SELECT
#   p.full_name AS patient_name,
#   p.mobile_phone AS patient_phone,
#   COUNT(a.patient_id) AS appointment_count
# FROM patient AS p
# JOIN appointment AS a
#   ON p.id = a.patient_id
# WHERE
#   a.appointment_time BETWEEN `2025-03-01` AND `2025-03-31 23:59:59`
# GROUP BY
#   p.id
# ORDER BY
#   appointment_count DESC
# LIMIT 1
# ----------Row 55---------
# Processing llm_row with question: Tìm tổng doanh thu từ các hóa đơn thuốc tại chi nhánh Cầu Giấy vào ngày 12/03/2025.
#
# skip candidate row:
# Tìm bệnh nhân có nhiều lịch hẹn nhất trong tháng 3 năm 2025.
#
# Error normalizing SQL: Invalid expression / Unexpected token. Line 2, Col: 31.
#   SELECT
#   SUM(SI.total_amount) AS `Tổng doanh thu`
# FROM sale_invoice AS SI
# JOIN branch AS B
#   ON SI.store_id = B.id
# WHERE
#   B.branch_name = at
# Query: SELECT
#   SUM(SI.total_amount) AS `Tổng doanh thu`
# FROM sale_invoice AS SI
# JOIN branch AS B
#   ON SI.store_id = B.id
# WHERE
#   B.branch_name = 'Chi nhánh Cầu Giấy' AND DATE(SI.created_on) = '2025-03-12'
# Error normalizing SQL: Invalid expression / Unexpected token. Line 2, Col: 31.
#   SELECT
#   SUM(SI.total_amount) AS `Tổng doanh thu`
# FROM sale_invoice AS SI
# JOIN branch AS B
#   ON SI.store_id = B.id
# WHERE
#   B.branch_name = at
# Query: SELECT
#   SUM(SI.total_amount) AS `Tổng doanh thu`
# FROM sale_invoice AS SI
# JOIN branch AS B
#   ON SI.store_id = B.id
# WHERE
#   B.branch_name = 'Chi nhánh Cầu Giấy' AND DATE(SI.created_on) = '2025-03-12'
# ----------Row 56---------
# Processing llm_row with question: Liệt kê các bệnh nhân có sinh nhật trong tháng 3 và đã đặt lịch hẹn trong tháng 3 năm 2025.
#
# skip candidate row:
# Tìm tổng doanh thu từ các hóa đơn thuốc tại chi nhánh Cầu Giấy vào ngày 12/03/2025.
#
# ----------Row 57---------
# Processing llm_row with question: Tìm tổng số tiền cọc (deposit) từ các hóa đơn dịch vụ tại chi nhánh Từ Liêm trong tháng 3 năm 2025.
#
# skip candidate row:
# Liệt kê các bệnh nhân có sinh nhật trong tháng 3 và đã đặt lịch hẹn trong tháng 3 năm 2025.
#
# ----------Row 58---------
# Processing llm_row with question: Tìm danh sách các bệnh nhân có khiếu nại và đã đặt lịch hẹn tại chi nhánh Cầu Giấy.
#
# skip candidate row:
# Tìm tổng số tiền cọc (deposit) từ các hóa đơn dịch vụ tại chi nhánh Từ Liêm trong tháng 3 năm 2025.
#
# Error normalizing SQL: Invalid expression / Unexpected token. Line 11, Col: 22.
#   ent AS a
#   ON p.id = a.patient_id
# JOIN branch AS b
#   ON a.branch_id = b.id
# WHERE
#   b.branch_name = `Chi nhánh Cầu Giấy` at
# Query: SELECT DISTINCT
#   p.full_name AS patient_name
# FROM patient AS p
# JOIN complaint AS c
#   ON p.id = c.patient_id
# JOIN appointment AS a
#   ON p.id = a.patient_id
# JOIN branch AS b
#   ON a.branch_id = b.id
# WHERE
#   b.branch_name = `Chi nhánh Cầu Giấy`
# ----------Row 59---------
# Processing llm_row with question: Tìm tổng số lượng lô hàng sắp hết hạn (expiry_status_id = 122) tại chi nhánh Hà Đông.
#
# skip candidate row:
# Tìm danh sách các bệnh nhân có khiếu nại và đã đặt lịch hẹn tại chi nhánh Cầu Giấy.
#
# ----------Row 60---------
# Processing llm_row with question: Tìm bệnh nhân có tổng số tiền hóa đơn dịch vụ lớn nhất trong tháng 3 năm 2025.
#
# skip candidate row:
# Tìm tổng số lượng lô hàng sắp hết hạn (expiry_status_id = 122) tại chi nhánh Hà Đông.
#
# Error normalizing SQL: Invalid expression / Unexpected token. Line 2, Col: 21.
#   SELECT
#   p.full_name AS `Tên bệnh nhân`,
#   p.patient_code AS `Mã bệnh nhân`,
#   SUM(si.total_amount) AS `Tổng tiền hóa đơn dịch v at
# Query: SELECT
#   p.full_name AS `Tên bệnh nhân`,
#   p.patient_code AS `Mã bệnh nhân`,
#   SUM(si.total_amount) AS `Tổng tiền hóa đơn dịch vụ`
# FROM patient AS p
# JOIN service_invoice AS si
#   ON p.id = si.patient_id
# WHERE
#   MONTH(si.paid_date) = 3 AND YEAR(si.paid_date) = 2025
# GROUP BY
#   p.id
# ORDER BY
#   SUM(si.total_amount) DESC
# LIMIT 1
# ----------Row 61---------
# Processing llm_row with question: Tìm danh sách các dịch vụ được sử dụng bởi bệnh nhân có id = 8946 trong tháng 3 năm 2025.
#
# skip candidate row:
# Tìm bệnh nhân có tổng số tiền hóa đơn dịch vụ lớn nhất trong tháng 3 năm 2025.
#
# ----------Row 62---------
# Processing llm_row with question: Tìm tổng số tiền giảm giá (discount) từ các hóa đơn dịch vụ tại chi nhánh Từ Liêm trong tháng 3 năm 2025.
#
# skip candidate row:
# Tìm danh sách các dịch vụ được sử dụng bởi bệnh nhân có id = 8946 trong tháng 3 năm 2025.
#
# ----------Row 63---------
# Processing llm_row with question: Tìm tổng số lượng dịch vụ được sử dụng bởi các bệnh nhân nữ trong tháng 3 năm 2025.
#
# skip candidate row:
# Tìm tổng số tiền giảm giá (discount) từ các hóa đơn dịch vụ tại chi nhánh Từ Liêm trong tháng 3 năm 2025.
#
# ----------Row 64---------
# Processing llm_row with question: Tìm tổng số tiền thanh toán bằng tiền mặt từ các hóa đơn dịch vụ tại chi nhánh Hà Đông vào ngày 12/03/2025.
#
# skip candidate row:
# Tìm tổng số lượng dịch vụ được sử dụng bởi các bệnh nhân nữ trong tháng 3 năm 2025.
#
# Error normalizing SQL: Invalid expression / Unexpected token. Line 2, Col: 34.
#   SELECT
#   SUM(SI.received_amount) AS `Tổng tiền thanh toán tiền mặt`
# FROM sale_invoice AS SI
# JOIN employee AS EM
#   ON SI.prescriber_id = EM.id at
# Query: SELECT
#   SUM(SI.received_amount) AS `Tổng tiền thanh toán tiền mặt`
# FROM sale_invoice AS SI
# JOIN employee AS EM
#   ON SI.prescriber_id = EM.id
# JOIN branch AS BR
#   ON EM.branch_id = BR.id
# WHERE
#   BR.branch_name = 'Chi nhánh Hà Đông'
#   AND SI.payment_mode = 'cash'
#   AND DATE(SI.created_on) = '2025-03-12'
# ----------Row 65---------
# Processing llm_row with question: Tìm danh sách các bệnh nhân có lịch hẹn với bác sĩ có id = 41 và đã thanh toán hóa đơn dịch vụ.
#
# skip candidate row:
# Tìm tổng số tiền thanh toán bằng tiền mặt từ các hóa đơn dịch vụ tại chi nhánh Hà Đông vào ngày 12/03/2025.
#
# ----------Row 66---------
# Processing llm_row with question: Tìm tổng số lượng lô hàng nhập kho từ nhà cung cấp trong tháng 3 năm 2025 tại chi nhánh Từ Liêm.
#
# skip candidate row:
# Tìm danh sách các bệnh nhân có lịch hẹn với bác sĩ có id = 41 và đã thanh toán hóa đơn dịch vụ.
#
# Error normalizing SQL: Invalid expression / Unexpected token. Line 2, Col: 33.
#   SELECT
#   SUM(T1.total_quantity) AS `Tổng số lượng lô hàng nhập kho`
# FROM transfer_in AS T1
# INNER JOIN store AS T2
#   ON T1.destination_store_ at
# Query: SELECT
#   SUM(T1.total_quantity) AS `Tổng số lượng lô hàng nhập kho`
# FROM transfer_in AS T1
# INNER JOIN store AS T2
#   ON T1.destination_store_id = T2.id
# INNER JOIN branch AS T3
#   ON T2.branch_id = T3.id
# WHERE
#   T3.branch_name = 'Chi nhánh Từ Liêm'
#   AND T1.transfer_in_date BETWEEN '2025-03-01' AND '2025-03-31'
# ----------Row 67---------
# Processing llm_row with question: Tìm tổng số tiền thanh toán bằng chuyển khoản từ các hóa đơn dịch vụ tại chi nhánh Cầu Giấy trong tháng 3 năm 2025.
#
# skip candidate row:
# Tìm tổng số lượng lô hàng nhập kho từ nhà cung cấp trong tháng 3 năm 2025 tại chi nhánh Từ Liêm.
#
# Error normalizing SQL: Invalid expression / Unexpected token. Line 7, Col: 23.
#   M service_invoice AS T1
# INNER JOIN branch AS T2
#   ON T1.branch_id = T2.id
# WHERE
#   T2.branch_name = `Chi nhánh Cầu Giấy`
#   AND T1.paid_date BETWEEN `2025-03-01` AND `2025-03-31` at
# Query: SELECT
#   SUM(T1.bank_transfer_amount) AS total_bank_transfer_amount
# FROM service_invoice AS T1
# INNER JOIN branch AS T2
#   ON T1.branch_id = T2.id
# WHERE
#   T2.branch_name = `Chi nhánh Cầu Giấy`
#   AND T1.paid_date BETWEEN `2025-03-01` AND `2025-03-31`
# ----------Row 68---------
# Processing llm_row with question: Tìm danh sách các bệnh nhân có khiếu nại và có lịch hẹn vào ngày 12/03/2025.
#
# skip candidate row:
# Tìm tổng số tiền thanh toán bằng chuyển khoản từ các hóa đơn dịch vụ tại chi nhánh Cầu Giấy trong tháng 3 năm 2025.
#
# ----------Row 69---------
# Processing llm_row with question: Tìm tổng số lượng dịch vụ được sử dụng bởi bệnh nhân có id = 8946 trong tất cả các chi nhánh.
#
# skip candidate row:
# Tìm danh sách các bệnh nhân có khiếu nại và có lịch hẹn vào ngày 12/03/2025.
#
# Error normalizing SQL: Invalid expression / Unexpected token. Line 2, Col: 26.
#   SELECT
#   SUM(s.quantity) AS `Tổng số lượng dịch vụ`
# FROM patient AS p
# JOIN service AS s
#   ON p.branch_id = s.service_info_id
# WHERE
#    at
# Query: SELECT
#   SUM(s.quantity) AS `Tổng số lượng dịch vụ`
# FROM patient AS p
# JOIN service AS s
#   ON p.branch_id = s.service_info_id
# WHERE
#   p.id = 8946
# ----------Row 70---------
# Processing llm_row with question: Tìm bệnh nhân có tổng số tiền công nợ lớn nhất trong tháng 3 năm 2025.
#
# skip candidate row:
# Tìm tổng số lượng dịch vụ được sử dụng bởi bệnh nhân có id = 8946 trong tất cả các chi nhánh.
#
# ----------Row 71---------
# Processing llm_row with question: Tìm tổng số tiền thanh toán bằng thẻ tín dụng từ các hóa đơn dịch vụ tại chi nhánh Từ Liêm trong tháng 3 năm 2025.
#
# skip candidate row:
# Tìm bệnh nhân có tổng số tiền công nợ lớn nhất trong tháng 3 năm 2025.
#
# ----------Row 72---------
# Processing llm_row with question: Tìm danh sách các bệnh nhân có lịch hẹn tại chi nhánh Cầu Giấy và có tổng số tiền hóa đơn thuốc lớn hơn 0.
#
# skip candidate row:
# Tìm tổng số tiền thanh toán bằng thẻ tín dụng từ các hóa đơn dịch vụ tại chi nhánh Từ Liêm trong tháng 3 năm 2025.
#
# Error normalizing SQL: Invalid expression / Unexpected token. Line 2, Col: 23.
#   SELECT
#   p.patient_code AS `Mã bệnh nhân`,
#   p.full_name AS `Tên bệnh nhân`,
#   p.mobile_phone AS `Số điện thoại`,
#   SUM(si.total_a at
# Query: SELECT
#   p.patient_code AS `Mã bệnh nhân`,
#   p.full_name AS `Tên bệnh nhân`,
#   p.mobile_phone AS `Số điện thoại`,
#   SUM(si.total_amount) AS `Tổng tiền hóa đơn`
# FROM patient AS p
# INNER JOIN appointment AS a
#   ON p.id = a.patient_id
# INNER JOIN branch AS b
#   ON a.branch_id = b.id
# INNER JOIN sale_invoice AS si
#   ON p.id = si.patient_id
# WHERE
#   b.branch_name = `Chi nhánh Cầu Giấy`
# GROUP BY
#   p.id,
#   p.patient_code,
#   p.full_name,
#   p.mobile_phone
# HAVING
#   SUM(si.total_amount) > 0
# Error normalizing SQL: Invalid expression / Unexpected token. Line 2, Col: 21.
#   SELECT DISTINCT
#   p.full_name AS `Tên bệnh nhân`,
#   p.patient_code AS `Mã bệnh nhân`,
#   p.mobile_phone AS `Số điện thoại`,
#   b.branch_nam at
# Query: SELECT DISTINCT
#   p.full_name AS `Tên bệnh nhân`,
#   p.patient_code AS `Mã bệnh nhân`,
#   p.mobile_phone AS `Số điện thoại`,
#   b.branch_name AS `Chi nhánh`,
#   SUM(si.total_amount) AS `Tổng tiền hóa đơn`
# FROM patient AS p
# JOIN appointment AS a
#   ON p.id = a.patient_id
# JOIN branch AS b
#   ON a.branch_id = b.id
# JOIN sale_invoice AS si
#   ON p.id = si.patient_id
# WHERE
#   b.branch_name = 'Chi nhánh Cầu Giấy'
# GROUP BY
#   p.id
# HAVING
#   SUM(si.total_amount) > 0
# ----------Row 73---------
# Processing llm_row with question: Tìm tổng số lượng lô hàng còn lại (remain_quantity) tại chi nhánh Hà Đông.
#
# skip candidate row:
# Tìm danh sách các bệnh nhân có lịch hẹn tại chi nhánh Cầu Giấy và có tổng số tiền hóa đơn thuốc lớn hơn 0.
#
# ----------Row 74---------
# Processing llm_row with question: Tìm danh sách các dịch vụ được sử dụng trong các lịch hẹn tại chi nhánh Từ Liêm trong tháng 3 năm 2025.
#
# skip candidate row:
# Tìm tổng số lượng lô hàng còn lại (remain_quantity) tại chi nhánh Hà Đông.
#
# ----------Row 75---------
# Processing llm_row with question: Tìm bệnh nhân có số lượng khiếu nại nhiều nhất trong tháng 3 năm 2025.
#
# skip candidate row:
# Tìm danh sách các dịch vụ được sử dụng trong các lịch hẹn tại chi nhánh Từ Liêm trong tháng 3 năm 2025.
#
# ----------Row 76---------
# Processing llm_row with question: Tìm tổng số tiền hóa đơn dịch vụ đã thanh toán tại chi nhánh Hà Đông trong tháng 3 năm 2025.
#
# skip candidate row:
# Tìm bệnh nhân có số lượng khiếu nại nhiều nhất trong tháng 3 năm 2025.
#
# Error normalizing SQL: Invalid expression / Unexpected token. Line 2, Col: 31.
#   SELECT
#   SUM(T1.total_amount) AS `Tổng tiền hóa đơn dịch vụ đã thanh toán`
# FROM receipt AS T1
# INNER JOIN service_invoice AS T2
#   ON T1.ser at
# Query: SELECT
#   SUM(T1.total_amount) AS `Tổng tiền hóa đơn dịch vụ đã thanh toán`
# FROM receipt AS T1
# INNER JOIN service_invoice AS T2
#   ON T1.service_invoice_id = T2.id
# INNER JOIN branch AS T3
#   ON T2.branch_id = T3.id
# WHERE
#   T3.branch_name = 'Chi nhánh Hà Đông'
#   AND T1.received_date BETWEEN '2025-03-01' AND '2025-03-31'
# ----------Row 77---------
# Processing llm_row with question: Tìm danh sách các bệnh nhân có lịch hẹn với kỹ thuật viên có id = 46 và đã thanh toán hóa đơn dịch vụ.
#
# skip candidate row:
# Tìm tổng số tiền hóa đơn dịch vụ đã thanh toán tại chi nhánh Hà Đông trong tháng 3 năm 2025.
#
# ----------Row 78---------
# Processing llm_row with question: Tìm tổng số lượng dịch vụ được sử dụng bởi các bệnh nhân nam trong tháng 3 năm 2025.
#
# skip candidate row:
# Tìm danh sách các bệnh nhân có lịch hẹn với kỹ thuật viên có id = 46 và đã thanh toán hóa đơn dịch vụ.
#
# ----------Row 79---------
# Processing llm_row with question: Tìm tổng số tiền công nợ từ các hóa đơn thuốc tại chi nhánh Từ Liêm trong tháng 3 năm 2025.
#
# skip candidate row:
# Tìm tổng số lượng dịch vụ được sử dụng bởi các bệnh nhân nam trong tháng 3 năm 2025.
#
# ----------Row 80---------
# Processing llm_row with question: Tìm danh sách các bệnh nhân có lịch hẹn tại chi nhánh Hà Đông và có khiếu nại trong tháng 3 năm 2025.
#
# skip candidate row:
# Tìm tổng số tiền công nợ từ các hóa đơn thuốc tại chi nhánh Từ Liêm trong tháng 3 năm 2025.
#
# ----------Row 81---------
# Processing llm_row with question: Tìm tổng số lượng lô hàng nhập kho có giá nhập lớn hơn 0 tại chi nhánh Cầu Giấy.
#
# skip candidate row:
# Tìm danh sách các bệnh nhân có lịch hẹn tại chi nhánh Hà Đông và có khiếu nại trong tháng 3 năm 2025.
#
# ----------Row 82---------
# Processing llm_row with question: Tìm danh sách các dịch vụ được sử dụng trong các lịch hẹn có bác sĩ có id = 41.
#
# skip candidate row:
# Tìm tổng số lượng lô hàng nhập kho có giá nhập lớn hơn 0 tại chi nhánh Cầu Giấy.
#
# Error normalizing SQL: Invalid expression / Unexpected token. Line 2, Col: 24.
#   SELECT DISTINCT
#   s.service_name AS `Tên dịch vụ`
# FROM appointment AS a
# JOIN appointment_service AS aps
#   ON a.id = aps.appointment_id
# JOIN  at
# Query: SELECT DISTINCT
#   s.service_name AS `Tên dịch vụ`
# FROM appointment AS a
# JOIN appointment_service AS aps
#   ON a.id = aps.appointment_id
# JOIN service AS s
#   ON aps.service_id = s.id
# WHERE
#   a.doctor_id = 41
# ----------Row 83---------
# Processing llm_row with question: Tìm bệnh nhân có tổng số tiền hóa đơn thuốc lớn nhất trong tháng 3 năm 2025.
#
# skip candidate row:
# Tìm danh sách các dịch vụ được sử dụng trong các lịch hẹn có bác sĩ có id = 41.
#
# ----------Row 84---------
# Processing llm_row with question: Tìm tổng số tiền giảm giá từ các hóa đơn thuốc tại chi nhánh Hà Đông trong tháng 3 năm 2025.
#
# skip candidate row:
# Tìm bệnh nhân có tổng số tiền hóa đơn thuốc lớn nhất trong tháng 3 năm 2025.
#
# ----------Row 85---------
# Processing llm_row with question: Tìm tổng số lượng dịch vụ được sử dụng trong các lịch hẹn bị hủy tại chi nhánh Cầu Giấy.
#
# skip candidate row:
# Tìm tổng số tiền giảm giá từ các hóa đơn thuốc tại chi nhánh Hà Đông trong tháng 3 năm 2025.
#
# Error normalizing SQL: Invalid expression / Unexpected token. Line 2, Col: 30.
#   SELECT
#   SUM(aps.service_id) AS `Tổng số lượng dịch vụ`
# FROM branch AS b
# INNER JOIN appointment AS a
#   ON b.id = a.branch_id
# INNER JOIN a at
# Query: SELECT
#   SUM(aps.service_id) AS `Tổng số lượng dịch vụ`
# FROM branch AS b
# INNER JOIN appointment AS a
#   ON b.id = a.branch_id
# INNER JOIN appointment_service AS aps
#   ON a.id = aps.appointment_id
# WHERE
#   b.branch_name = 'Chi nhánh Cầu Giấy' AND NOT a.cancelled_by IS NULL
# ----------Row 86---------
# Processing llm_row with question: Tìm bệnh nhân có tổng số tiền cọc lớn nhất trong tháng 3 năm 2025.
#
# skip candidate row:
# Tìm tổng số lượng dịch vụ được sử dụng trong các lịch hẹn bị hủy tại chi nhánh Cầu Giấy.
#
# Error normalizing SQL: Invalid expression / Unexpected token. Line 2, Col: 18.
#   SELECT
#   full_name AS `Họ và tên`,
#   patient_code AS `Mã bệnh nhân`,
#   mobile_phone AS `Số điện thoại`,
#   money_total AS `Tổn at
# Query: SELECT
#   full_name AS `Họ và tên`,
#   patient_code AS `Mã bệnh nhân`,
#   mobile_phone AS `Số điện thoại`,
#   money_total AS `Tổng tiền đã thanh toán`
# FROM patient
# WHERE
#   MONTH(modified_on) = 3 AND YEAR(modified_on) = 2025
# ORDER BY
#   money_total DESC
# LIMIT 1
# ----------Row 87---------
# Processing llm_row with question: Tìm tổng số tiền thanh toán bằng tiền mặt từ các hóa đơn thuốc tại chi nhánh Từ Liêm trong tháng 3 năm 2025.
#
# skip candidate row:
# Tìm bệnh nhân có tổng số tiền cọc lớn nhất trong tháng 3 năm 2025.
#
# Error normalizing SQL: Invalid expression / Unexpected token. Line 2, Col: 31.
#   SELECT
#   SUM(SI.total_amount) AS `Tổng tiền thanh toán bằng tiền mặt`
# FROM sale_invoice AS SI
# JOIN store AS S
#   ON SI.store_id = S.id
# JOIN at
# Query: SELECT
#   SUM(SI.total_amount) AS `Tổng tiền thanh toán bằng tiền mặt`
# FROM sale_invoice AS SI
# JOIN store AS S
#   ON SI.store_id = S.id
# JOIN branch AS B
#   ON S.branch_id = B.id
# WHERE
#   B.branch_name = 'Chi nhánh Từ Liêm'
#   AND SI.payment_mode = 'cash'
#   AND SI.created_on BETWEEN '2025-03-01' AND '2025-03-31'
# ----------Row 88---------
# Processing llm_row with question: Tìm danh sách các bệnh nhân có lịch hẹn tại chi nhánh Cầu Giấy và có tổng số tiền công nợ lớn hơn 0.
#
# skip candidate row:
# Tìm tổng số tiền thanh toán bằng tiền mặt từ các hóa đơn thuốc tại chi nhánh Từ Liêm trong tháng 3 năm 2025.
#
# Error normalizing SQL: Invalid expression / Unexpected token. Line 2, Col: 21.
#   SELECT DISTINCT
#   p.full_name AS `Tên bệnh nhân`,
#   p.patient_code AS `Mã bệnh nhân`,
#   p.mobile_phone AS `Số điện thoại`,
#   b.branch_nam at
# Query: SELECT DISTINCT
#   p.full_name AS `Tên bệnh nhân`,
#   p.patient_code AS `Mã bệnh nhân`,
#   p.mobile_phone AS `Số điện thoại`,
#   b.branch_name AS `Chi nhánh`,
#   SUM(si.total_amount) AS `Tổng tiền`
# FROM patient AS p
# JOIN appointment AS a
#   ON p.id = a.patient_id
# JOIN branch AS b
#   ON a.branch_id = b.id
# LEFT JOIN sale_invoice AS si
#   ON p.id = si.patient_id
# WHERE
#   b.branch_name = 'Chi nhánh Cầu Giấy'
# GROUP BY
#   p.id
# HAVING
#   SUM(si.total_amount) > 0
# ----------Row 89---------
# Processing llm_row with question: Tìm tổng số lượng lô hàng hết hạn (expiry_status_id = 123) tại chi nhánh Hà Đông.
#
# skip candidate row:
# Tìm danh sách các bệnh nhân có lịch hẹn tại chi nhánh Cầu Giấy và có tổng số tiền công nợ lớn hơn 0.
#
# ----------Row 90---------
# Processing llm_row with question: Tìm danh sách các dịch vụ được sử dụng trong các lịch hẹn có kỹ thuật viên có id = 46.
#
# skip candidate row:
# Tìm tổng số lượng lô hàng hết hạn (expiry_status_id = 123) tại chi nhánh Hà Đông.
#
# ----------Row 91---------
# Processing llm_row with question: Tìm bệnh nhân có tổng số tiền thanh toán bằng chuyển khoản lớn nhất trong tháng 3 năm 2025.
#
# skip candidate row:
# Tìm danh sách các dịch vụ được sử dụng trong các lịch hẹn có kỹ thuật viên có id = 46.
#
# ----------Row 92---------
# Processing llm_row with question: Tìm tổng số tiền thanh toán bằng thẻ tín dụng từ các hóa đơn thuốc tại chi nhánh Cầu Giấy trong tháng 3 năm 2025.
#
# skip candidate row:
# Tìm bệnh nhân có tổng số tiền thanh toán bằng chuyển khoản lớn nhất trong tháng 3 năm 2025.
#
# Error normalizing SQL: Invalid expression / Unexpected token. Line 2, Col: 31.
#   SELECT
#   SUM(SI.total_amount) AS `Tổng tiền thanh toán bằng thẻ tín dụng`
# FROM sale_invoice AS SI
# JOIN branch AS B
#   ON SI.store_id = B.id at
# Query: SELECT
#   SUM(SI.total_amount) AS `Tổng tiền thanh toán bằng thẻ tín dụng`
# FROM sale_invoice AS SI
# JOIN branch AS B
#   ON SI.store_id = B.id
# JOIN payment AS P
#   ON SI.payment_mode = P.payment_code
# WHERE
#   B.branch_name = 'Chi nhánh Cầu Giấy'
#   AND P.payment_name = 'Thanh toán thẻ'
#   AND SI.paid_date BETWEEN '2025-03-01' AND '2025-03-31'
# ----------Row 93---------
# Processing llm_row with question: Tìm danh sách các bệnh nhân có lịch hẹn tại chi nhánh Hà Đông và có tổng số tiền cọc lớn hơn 0.
#
# skip candidate row:
# Tìm tổng số tiền thanh toán bằng thẻ tín dụng từ các hóa đơn thuốc tại chi nhánh Cầu Giấy trong tháng 3 năm 2025.
#
# Error normalizing SQL: Invalid expression / Unexpected token. Line 2, Col: 21.
#   SELECT DISTINCT
#   p.full_name AS `Tên bệnh nhân`,
#   p.patient_code AS `Mã bệnh nhân`,
#   p.mobile_phone AS `Số điện thoại`,
#   b.branch_nam at
# Query: SELECT DISTINCT
#   p.full_name AS `Tên bệnh nhân`,
#   p.patient_code AS `Mã bệnh nhân`,
#   p.mobile_phone AS `Số điện thoại`,
#   b.branch_name AS `Chi nhánh`,
#   p.money_total AS `Tổng tiền`
# FROM patient AS p
# JOIN appointment AS a
#   ON p.id = a.patient_id
# JOIN branch AS b
#   ON a.branch_id = b.id
# WHERE
#   b.branch_name = 'Chi nhánh Hà Đông' AND p.money_total > 0
# ----------Row 94---------
# Processing llm_row with question: Tìm tổng số lượng dịch vụ được sử dụng trong các lịch hẹn có trạng thái "Đã xác nhận" tại chi nhánh Từ Liêm.
#
# skip candidate row:
# Tìm danh sách các bệnh nhân có lịch hẹn tại chi nhánh Hà Đông và có tổng số tiền cọc lớn hơn 0.
#
# ----------Row 95---------
# Processing llm_row with question: Tìm bệnh nhân có tổng số tiền thanh toán bằng tiền mặt lớn nhất trong tháng 3 năm 2025.
#
# skip candidate row:
# ...
#
# skip candidate row:
# Tìm các lịch hẹn có mã bắt đầu bằng 'AP8946'.
#
# Error normalizing SQL: Invalid expression / Unexpected token. Line 2, Col: 27.
#   SELECT
#   a.appointment_code AS `Mã cuộc hẹn`,
#   a.full_name AS `Tên bệnh nhân`,
#   a.mobile_phone AS `Số điện thoại`
# FROM appointment A at
# Query: SELECT
#   a.appointment_code AS `Mã cuộc hẹn`,
#   a.full_name AS `Tên bệnh nhân`,
#   a.mobile_phone AS `Số điện thoại`
# FROM appointment AS a
# WHERE
#   a.full_name IN (
#     SELECT
#       full_name
#     FROM appointment
#     GROUP BY
#       full_name
#     HAVING
#       COUNT(DISTINCT mobile_phone) > 1
#   )
# ORDER BY
#   a.full_name
# ----------Row 253---------
# Processing llm_row with question: Có bao nhiêu lịch hẹn có 'remarks' không rỗng và 'content' cũng không rỗng?
#
# skip candidate row:
# Liệt kê các lịch hẹn có cùng tên bệnh nhân nhưng khác số điện thoại.
#
# ----------Row 254---------
# Processing llm_row with question: Tìm các lịch hẹn có ngày tạo là ngày đầu tiên của tháng.
#
# skip candidate row:
# Có bao nhiêu lịch hẹn có 'remarks' không rỗng và 'content' cũng không rỗng?
#
# ----------Row 255---------
# Processing llm_row with question: Liệt kê các lịch hẹn được tạo bởi người có tên 'Vttech' hoặc 'Admin'.
#
# skip candidate row:
# Tìm các lịch hẹn có ngày tạo là ngày đầu tiên của tháng.
#
# ----------Row 256---------
# Processing llm_row with question: Số lượng lịch hẹn của bác sĩ ID 25 theo từng chi nhánh.
#
# skip candidate row:
# Liệt kê các lịch hẹn được tạo bởi người có tên 'Vttech' hoặc 'Admin'.
#
# Error normalizing SQL: Invalid expression / Unexpected token. Line 2, Col: 23.
#   SELECT
#   b.branch_name AS `Tên chi nhánh`,
#   COUNT(a.id) AS `Số lượng lịch hẹn`
# FROM appointment AS a
# JOIN employee AS e
#   ON a.do at
# Query: SELECT
#   b.branch_name AS `Tên chi nhánh`,
#   COUNT(a.id) AS `Số lượng lịch hẹn`
# FROM appointment AS a
# JOIN employee AS e
#   ON a.doctor_id = e.id
# JOIN branch AS b
#   ON a.branch_id = b.id
# WHERE
#   a.doctor_id = 25
# GROUP BY
#   b.branch_name
# ----------Row 257---------
# Processing llm_row with question: Tìm các bệnh nhân có số điện thoại chứa '666'.
#
# skip candidate row:
# Số lượng lịch hẹn của bác sĩ ID 25 theo từng chi nhánh.
#
# ----------Row 258---------
# Processing llm_row with question: Có bao nhiêu lịch hẹn có thời gian ước tính là 30, 60, hoặc 90 phút?
#
# skip candidate row:
# Tìm các bệnh nhân có số điện thoại chứa '666'.
#
# ----------Row 259---------
# Processing llm_row with question: Bệnh nhân nào có lịch hẹn gần đây nhất?
#
# skip candidate row:
# Có bao nhiêu lịch hẹn có thời gian ước tính là 30, 60, hoặc 90 phút?
#
# ----------Row 260---------
# Processing llm_row with question: Liệt kê các lịch hẹn có ngày tạo và ngày hẹn cách nhau hơn 7 ngày.
#
# skip candidate row:
# Bệnh nhân nào có lịch hẹn gần đây nhất?
#
# ----------Row 261---------
# Processing llm_row with question: Số lượng bệnh nhân theo từng loại thành viên.
#
# skip candidate row:
# Liệt kê các lịch hẹn có ngày tạo và ngày hẹn cách nhau hơn 7 ngày.
#
# ----------Row 262---------
# Processing llm_row with question: Tìm tên bệnh nhân và mã lịch hẹn cho các lịch hẹn được tạo bởi người dùng có ID 1 và thực hiện bởi nhân viên có ID 1.
#
# skip candidate row:
# Số lượng bệnh nhân theo từng loại thành viên.
#
# ----------Row 263---------
# Processing llm_row with question: Liệt kê các lịch hẹn không có dịch vụ nào được đính kèm.
#
# skip candidate row:
# Tìm tên bệnh nhân và mã lịch hẹn cho các lịch hẹn được tạo bởi người dùng có ID 1 và thực hiện bởi nhân viên có ID 1.
#
# Error normalizing SQL: Invalid expression / Unexpected token. Line 2, Col: 27.
#   SELECT
#   a.appointment_code AS `Mã cuộc hẹn`,
#   a.full_name AS `Tên người hẹn`,
#   a.mobile_phone AS `Số điện thoại`,
#   a.appointment_t at
# Query: SELECT
#   a.appointment_code AS `Mã cuộc hẹn`,
#   a.full_name AS `Tên người hẹn`,
#   a.mobile_phone AS `Số điện thoại`,
#   a.appointment_time AS `Thời gian cuộc hẹn`,
#   a.content AS `Nội dung`,
#   a.remarks AS `Ghi chú`
# FROM appointment AS a
# LEFT JOIN appointment_service AS aps
#   ON a.id = aps.appointment_id
# WHERE
#   aps.id IS NULL
# ----------Row 264---------
# Processing llm_row with question: Số lượng lịch hẹn được tạo vào mỗi ngày trong tuần (Thứ 2, Thứ 3,...).
#
# skip candidate row:
# Liệt kê các lịch hẹn không có dịch vụ nào được đính kèm.
#
# ----------Row 265---------
# Processing llm_row with question: Liệt kê các lịch hẹn có cùng tên bệnh nhân, cùng ngày hẹn nhưng khác bác sĩ.
#
# skip candidate row:
# Số lượng lịch hẹn được tạo vào mỗi ngày trong tuần (Thứ 2, Thứ 3,...).
#
# ----------Row 266---------
# Processing llm_row with question: Trung bình có bao nhiêu dịch vụ trên mỗi lịch hẹn?
#
# skip candidate row:
# Liệt kê các lịch hẹn có cùng tên bệnh nhân, cùng ngày hẹn nhưng khác bác sĩ.
#
# ----------Row 267---------
# Processing llm_row with question: Liệt kê các lịch hẹn mà tên người tạo (creator) là 'Admin' và tên bệnh nhân là 'Cường nguyễn'.
#
# skip candidate row:
# Trung bình có bao nhiêu dịch vụ trên mỗi lịch hẹn?
#
# Error normalizing SQL: Invalid expression / Unexpected token. Line 2, Col: 27.
#   SELECT
#   a.appointment_code AS `Mã cuộc hẹn`,
#   p.full_name AS `Tên bệnh nhân`,
#   a.appointment_time AS `Thời gian cuộc hẹn`,
#   a.cont at
# Query: SELECT
#   a.appointment_code AS `Mã cuộc hẹn`,
#   p.full_name AS `Tên bệnh nhân`,
#   a.appointment_time AS `Thời gian cuộc hẹn`,
#   a.content AS `Nội dung cuộc hẹn`,
#   a.remarks AS `Ghi chú`,
#   a.creator AS `Người tạo`
# FROM appointment AS a
# JOIN patient AS p
#   ON a.patient_id = p.id
# WHERE
#   a.creator = 'Admin' AND p.full_name = 'Cường nguyễn'
# ----------Row 268---------
# Processing llm_row with question: Có bao nhiêu bệnh nhân có lịch hẹn trong 6 tháng qua nhưng không có lịch hẹn trong tháng này?
#
# skip candidate row:
# Liệt kê các lịch hẹn mà tên người tạo (creator) là 'Admin' và tên bệnh nhân là 'Cường nguyễn'.
#
# Error normalizing SQL: Invalid expression / Unexpected token. Line 2, Col: 29.
#   SELECT
#   COUNT(DISTINCT p.id) AS `Số lượng bệnh nhân`
# FROM patient AS p
# WHERE
#   p.id IN (
#     SELECT DISTINCT
#       patient_id
#     FROM  at
# Query: SELECT
#   COUNT(DISTINCT p.id) AS `Số lượng bệnh nhân`
# FROM patient AS p
# WHERE
#   p.id IN (
#     SELECT DISTINCT
#       patient_id
#     FROM appointment
#     WHERE
#       appointment_time >= DATE_SUB(CURDATE(), INTERVAL (INTERVAL '6' MONTH) DAY)
#   )
#   AND NOT p.id IN (
#     SELECT DISTINCT
#       patient_id
#     FROM appointment
#     WHERE
#       MONTH(appointment_time) = MONTH(CURDATE())
#       AND YEAR(appointment_time) = YEAR(CURDATE())
#   )
# ----------Row 269---------
# Processing llm_row with question: Liệt kê tất cả các bệnh nhân nam?
#
# skip candidate row:
# Có bao nhiêu bệnh nhân có lịch hẹn trong 6 tháng qua nhưng không có lịch hẹn trong tháng này?
#
# Error normalizing SQL: Invalid expression / Unexpected token. Line 2, Col: 21.
#   SELECT
#   patient_code AS `Mã bệnh nhân`,
#   full_name AS `Họ và tên`,
#   date_of_birth AS `Ngày sinh`,
#   mobile_phone AS `Số điện  at
# Query: SELECT
#   patient_code AS `Mã bệnh nhân`,
#   full_name AS `Họ và tên`,
#   date_of_birth AS `Ngày sinh`,
#   mobile_phone AS `Số điện thoại`,
#   address AS `Địa chỉ`
# FROM patient
# WHERE
#   sex = 1
# ----------Row 270---------
# Processing llm_row with question: Cho biết tên và mã của tất cả các chi nhánh hiện có?
#
# skip candidate row:
# Liệt kê tất cả các bệnh nhân nam?
#
# ----------Row 271---------
# Processing llm_row with question: Có bao nhiêu lịch hẹn đã được tạo vào ngày 12 tháng 3 năm 2025?
#
# skip candidate row:
# Cho biết tên và mã của tất cả các chi nhánh hiện có?
#
# ----------Row 272---------
# Processing llm_row with question: Liệt kê tên đầy đủ và số điện thoại của các bệnh nhân có tên là 'Cường nguyễn'?
#
# skip candidate row:
# Có bao nhiêu lịch hẹn đã được tạo vào ngày 12 tháng 3 năm 2025?
#
# Error normalizing SQL: Invalid expression / Unexpected token. Line 2, Col: 19.
#   SELECT
#   full_name AS `Tên bệnh nhân`,
#   mobile_phone AS `Số điện thoại`
# FROM patient
# WHERE
#   full_name LIKE '%Cường nguyễn%' at
# Query: SELECT
#   full_name AS `Tên bệnh nhân`,
#   mobile_phone AS `Số điện thoại`
# FROM patient
# WHERE
#   full_name LIKE '%Cường nguyễn%'
# Error normalizing SQL: Invalid expression / Unexpected token. Line 2, Col: 19.
#   SELECT
#   full_name AS `Tên đầy đủ`,
#   mobile_phone AS `Số điện thoại`
# FROM patient
# WHERE
#   full_name = 'Cường nguyễn' at
# Query: SELECT
#   full_name AS `Tên đầy đủ`,
#   mobile_phone AS `Số điện thoại`
# FROM patient
# WHERE
#   full_name = 'Cường nguyễn'
# ----------Row 273---------
# Processing llm_row with question: Tìm các lịch hẹn được thực hiện bởi nhân viên có tên 'Admin'?
#
# skip candidate row:
# Liệt kê tên đầy đủ và số điện thoại của các bệnh nhân có tên là 'Cường nguyễn'?
#
# ----------Row 274---------
# Processing llm_row with question: Liệt kê các dịch vụ có trong lịch hẹn với mã 'AP89451741761167'?
#
# skip candidate row:
# Tìm các lịch hẹn được thực hiện bởi nhân viên có tên 'Admin'?
#
# ----------Row 275---------
# Processing llm_row with question: Tổng số tiền của tất cả các hóa đơn dịch vụ đã thanh toán (bill_status_id = 54) là bao nhiêu?
#
# skip candidate row:
# Liệt kê các dịch vụ có trong lịch hẹn với mã 'AP89451741761167'?
#
# ----------Row 276---------
# Processing llm_row with question: Liệt kê tên các bác sĩ (job_title_id = 92 hoặc 96) và chi nhánh họ làm việc?
#
# skip candidate row:
# Tổng số tiền của tất cả các hóa đơn dịch vụ đã thanh toán (bill_status_id = 54) là bao nhiêu?
#
# ----------Row 277---------
# Processing llm_row with question: Bệnh nhân nào đã đặt lịch hẹn nhiều nhất và số lần đặt là bao nhiêu?
#
# skip candidate row:
# Liệt kê tên các bác sĩ (job_title_id = 92 hoặc 96) và chi nhánh họ làm việc?
#
# ----------Row 278---------
# Processing llm_row with question: Cho biết tổng số lượng các mặt hàng đã được xuất kho trong ngày 21 tháng 3 năm 2025?
#
# skip candidate row:
# Bệnh nhân nào đã đặt lịch hẹn nhiều nhất và số lần đặt là bao nhiêu?
#
# ----------Row 279---------
# Processing llm_row with question: Liệt kê các bệnh nhân đã thực hiện dịch vụ "Triệt lông ấn đường" và ngày thực hiện?
#
# skip candidate row:
# Cho biết tổng số lượng các mặt hàng đã được xuất kho trong ngày 21 tháng 3 năm 2025?
#
# Error normalizing SQL: Invalid expression / Unexpected token. Line 2, Col: 21.
#   SELECT
#   p.full_name AS `Tên bệnh nhân`,
#   s.deal_date AS `Ngày thực hiện`
# FROM patient AS p
# JOIN complaint AS c
#   ON p.id = c.p at
# Query: SELECT
#   p.full_name AS `Tên bệnh nhân`,
#   s.deal_date AS `Ngày thực hiện`
# FROM patient AS p
# JOIN complaint AS c
#   ON p.id = c.patient_id
# JOIN service AS s
#   ON c.service_id = s.id
# WHERE
#   c.service_name = 'Triệt lông ấn đường'
# Error normalizing SQL: Invalid expression / Unexpected token. Line 2, Col: 21.
#   SELECT DISTINCT
#   p.full_name AS `Tên bệnh nhân`,
#   s.deal_date AS `Ngày thực hiện dịch vụ`
# FROM patient AS p
# JOIN complaint AS c
#   ON p. at
# Query: SELECT DISTINCT
#   p.full_name AS `Tên bệnh nhân`,
#   s.deal_date AS `Ngày thực hiện dịch vụ`
# FROM patient AS p
# JOIN complaint AS c
#   ON p.id = c.patient_id
# JOIN service AS s
#   ON c.service_id = s.id
# WHERE
#   c.service_name = 'Triệt lông ấn đường'
# ----------Row 280---------
# Processing llm_row with question: Có bao nhiêu lịch hẹn được tạo bởi nhân viên 'Admin' tại chi nhánh 'Chi nhánh Hà Đông'?
#
# skip candidate row:
# Liệt kê các bệnh nhân đã thực hiện dịch vụ "Triệt lông ấn đường" và ngày thực hiện?
#
# Error normalizing SQL: Invalid expression / Unexpected token. Line 2, Col: 29.
#   SELECT
#   COUNT(DISTINCT a.id) AS `Số lượng lịch hẹn`
# FROM appointment AS a
# JOIN branch AS b
#   ON a.branch_id = b.id
# WHERE
#   a.creator =  at
# Query: SELECT
#   COUNT(DISTINCT a.id) AS `Số lượng lịch hẹn`
# FROM appointment AS a
# JOIN branch AS b
#   ON a.branch_id = b.id
# WHERE
#   a.creator = 'Admin' AND b.branch_name = 'Chi nhánh Hà Đông'
# ----------Row 281---------
# Processing llm_row with question: Đếm số lượng bệnh nhân theo từng loại thành viên (membership_type)?
#
# skip candidate row:
# Có bao nhiêu lịch hẹn được tạo bởi nhân viên 'Admin' tại chi nhánh 'Chi nhánh Hà Đông'?
#
# ----------Row 282---------
# Processing llm_row with question: Liệt kê các phiếu thu (receipt) cùng với tổng số tiền và tên bệnh nhân, được tạo trong ngày 12 tháng 3 năm 2025?
#
# skip candidate row:
# Đếm số lượng bệnh nhân theo từng loại thành viên (membership_type)?
#
# Error normalizing SQL: Invalid expression / Unexpected token. Line 2, Col: 20.
#   SELECT
#   receipt_num AS `Số biên lai`,
#   total_amount AS `Tổng tiền`
# FROM receipt
# WHERE
#   DATE(created_on) = '2025-03-12' at
# Query: SELECT
#   receipt_num AS `Số biên lai`,
#   total_amount AS `Tổng tiền`
# FROM receipt
# WHERE
#   DATE(created_on) = '2025-03-12'
# ----------Row 283---------
# Processing llm_row with question: Tìm tổng doanh thu từ các hóa đơn (sale_invoice) cho bệnh nhân 'Anh Thư'?
#
# skip candidate row:
# Liệt kê các phiếu thu (receipt) cùng với tổng số tiền và tên bệnh nhân, được tạo trong ngày 12 tháng 3 năm 2025?
#
# Error normalizing SQL: Invalid expression / Unexpected token. Line 2, Col: 41.
#   SELECT
#   SUM(sale_invoice.total_amount) AS `Tổng doanh thu`
# FROM sale_invoice
# JOIN patient
#   ON sale_invoice.patient_id = patient.id
# WHERE
#   patient at
# Query: SELECT
#   SUM(sale_invoice.total_amount) AS `Tổng doanh thu`
# FROM sale_invoice
# JOIN patient
#   ON sale_invoice.patient_id = patient.id
# WHERE
#   patient.full_name = 'Anh Thư'
# Error normalizing SQL: Invalid expression / Unexpected token. Line 2, Col: 31.
#   SELECT
#   SUM(si.total_amount) AS `Tổng doanh thu`
# FROM sale_invoice AS si
# JOIN patient AS p
#   ON si.patient_id = p.id
# WHERE
#   p.full_name  at
# Query: SELECT
#   SUM(si.total_amount) AS `Tổng doanh thu`
# FROM sale_invoice AS si
# JOIN patient AS p
#   ON si.patient_id = p.id
# WHERE
#   p.full_name = 'Anh Thư'
# ----------Row 284---------
# Processing llm_row with question: Liệt kê 5 dịch vụ (service_info) được sử dụng nhiều nhất trong các lịch hẹn?
#
# skip candidate row:
# Tìm tổng doanh thu từ các hóa đơn (sale_invoice) cho bệnh nhân 'Anh Thư'?
#
# Error normalizing SQL: Invalid expression / Unexpected token. Line 2, Col: 30.
#   SELECT
#   si.service_info_name AS `Tên dịch vụ`,
#   COUNT(asi.service_info_id) AS `Số lần sử dụng`
# FROM appointment_service AS asi
# JOIN ser at
# Query: SELECT
#   si.service_info_name AS `Tên dịch vụ`,
#   COUNT(asi.service_info_id) AS `Số lần sử dụng`
# FROM appointment_service AS asi
# JOIN service_info AS si
#   ON asi.service_info_id = si.id
# GROUP BY
#   asi.service_info_id
# ORDER BY
#   COUNT(asi.service_info_id) DESC
# LIMIT 5
# ----------Row 285---------
# Processing llm_row with question: Bệnh nhân nào có nhiều lịch hẹn bị hủy (appointment_status_id = 20) nhất?
#
# skip candidate row:
# Liệt kê 5 dịch vụ (service_info) được sử dụng nhiều nhất trong các lịch hẹn?
#
# ----------Row 286---------
# Processing llm_row with question: Liệt kê các nhân viên và số lượng lịch hẹn họ đã tạo, sắp xếp giảm dần theo số lượng lịch hẹn?
#
# skip candidate row:
# Bệnh nhân nào có nhiều lịch hẹn bị hủy (appointment_status_id = 20) nhất?
#
# ----------Row 287---------
# Processing llm_row with question: Tìm thông tin các gói (package) được mua bởi bệnh nhân có mã 'KH 000553'?
#
# skip candidate row:
# Liệt kê các nhân viên và số lượng lịch hẹn họ đã tạo, sắp xếp giảm dần theo số lượng lịch hẹn?
#
# Error normalizing SQL: Invalid expression / Unexpected token. Line 2, Col: 23.
#   SELECT
#   p.package_code AS `Mã gói`,
#   p.package_name AS `Tên gói`,
#   p.purchase_date AS `Ngày mua`,
#   p.total_amount AS `Tổng tiề at
# Query: SELECT
#   p.package_code AS `Mã gói`,
#   p.package_name AS `Tên gói`,
#   p.purchase_date AS `Ngày mua`,
#   p.total_amount AS `Tổng tiền`
# FROM package AS p
# JOIN patient AS pt
#   ON p.patient_id = pt.id
# WHERE
#   pt.patient_code = 'KH 000553'
# Error normalizing SQL: Invalid expression / Unexpected token. Line 2, Col: 23.
#   SELECT
#   p.package_code AS `Mã gói`,
#   p.package_name AS `Tên gói`,
#   p.purchase_date AS `Ngày mua`,
#   p.total_amount AS `Tổng tiề at
# Query: SELECT
#   p.package_code AS `Mã gói`,
#   p.package_name AS `Tên gói`,
#   p.purchase_date AS `Ngày mua`,
#   p.total_amount AS `Tổng tiền`,
#   pa.full_name AS `Tên bệnh nhân`
# FROM package AS p
# JOIN patient AS pa
#   ON p.patient_id = pa.id
# WHERE
#   pa.patient_code = 'KH 000553'
# ----------Row 288---------
# Processing llm_row with question: Chi nhánh nào có nhiều lịch hẹn nhất?
#
# skip candidate row:
# Tìm thông tin các gói (package) được mua bởi bệnh nhân có mã 'KH 000553'?

# %%
df.to_csv(
    csv_result_path,
    encoding="utf-8",
    quoting=1,  # QUOTE_ALL mode
    escapechar="\\",
)

# %%
for idx, row in df.iterrows():
    df.at[idx, "candidate_passes"] = [CANDIDATE_NAMES[i] for i, (em, ex) in enumerate(zip(row['candidate_em'], row['candidate_ex'])) if em or ex]

# %%
df.iloc[-5:]
# Out:
#                                               question  \
# 284  Liệt kê 5 dịch vụ (service_info) được sử dụng ...
# 285  Bệnh nhân nào có nhiều lịch hẹn bị hủy (appoin...
# 286  Liệt kê các nhân viên và số lượng lịch hẹn họ ...
# 287  Tìm thông tin các gói (package) được mua bởi b...
# 288            Chi nhánh nào có nhiều lịch hẹn nhất?\n
#
#                                       ground_truth_sql level  \
# 284  SELECT si.service_info_name, COUNT(aps.id) AS ...  hard
# 285  SELECT p.full_name, COUNT(a.id) AS so_lich_huy...  hard
# 286  SELECT e.first_name, e.last_name, COUNT(a.id) ...  hard
# 287  SELECT pkg.* FROM package pkg JOIN patient p O...  hard
# 288  SELECT b.branch_name, COUNT(a.id) AS total_app...  hard
#
#                                    ground_truth_result  error  \
# 284  [('Phuong Test', 8), ('Gói điều trị thâm vùng ...    NaN
# 285                              [('Cường nguyễn', 5)]    NaN
# 286  [('Admin', None, 95), ('Cường Cầu giấy', 'Cườn...    NaN
# 287  [(datetime.datetime(2025, 4, 17, 13, 17, 32, 8...    NaN
# 288                       [('Chi nhánh Cầu Giấy', 63)]    NaN
#
#                                    generated_sql_query  \
# 284  SELECT si.service_info_name AS 'Tên dịch vụ', ...
# 285  SELECT p.full_name AS patient_name, COUNT(a.pa...
# 286  SELECT e.first_name, e.last_name, COUNT(a.id) ...
# 287  SELECT p.package_code AS 'Mã gói', p.package_n...
# 288  SELECT b.branch_name, COUNT(a.id) AS total_app...
#
#                                 generated_query_result  generated_sql_error  \
# 284  Dưới đây là danh sách 5 dịch vụ được sử dụng n...                  NaN
# 285  Bệnh nhân có nhiều lịch hẹn bị hủy nhất là Cườ...                  NaN
# 286  Dưới đây là danh sách nhân viên và số lượng lị...                  NaN
# 287  Thông tin về các gói mà bệnh nhân có mã 'KH 00...                  NaN
# 288  Chi nhánh Cầu Giấy có nhiều lịch hẹn nhất, với...                  NaN
#
#                                   generated_raw_result llm_exact_match  \
# 284  [('Phuong Test', 8), ('Gói điều trị thâm vùng ...            True
# 285                              [('Cường nguyễn', 5)]            True
# 286  [('Admin', None, 95), ('Cường Cầu giấy', 'Cườn...             NaN
# 287  [('GDV20250417201732531', None, datetime.datet...           False
# 288                       [('Chi nhánh Cầu Giấy', 63)]            True
#
#     llm_execution_match                              candidate_generations  \
# 284                True  [SELECT\n  si.service_info_name,\n  COUNT(aps....
# 285                True  [SELECT\n  p.id AS patient_id,\n  p.full_name ...
# 286                 NaN  [SELECT\n  e.id AS employee_id,\n  e.first_nam...
# 287               False  [SELECT\n  p.id AS package_id,\n  p.package_co...
# 288                True  [SELECT\n  b.branch_name,\n  COUNT(a.id) AS to...
#
#                      candidate_em                  candidate_ex  \
# 284  [False, False, False, False]      [True, True, True, True]
# 285  [False, False, False, False]    [False, True, False, True]
# 286  [False, False, False, False]   [False, False, False, True]
# 287  [False, False, False, False]  [False, False, False, False]
# 288  [False, False, False, False]      [True, True, True, True]
#
#                                candidate_least_correct  \
# 284  [SELECT\n  si.service_info_name,\n  COUNT(aps....
# 285  [SELECT\n  p.full_name AS patient_name,\n  COU...
# 286  [SELECT\n  e.first_name,\n  e.last_name,\n  CO...
# 287                                                 []
# 288  [SELECT\n  b.branch_name,\n  COUNT(a.id) AS to...
#
#                                       candidate_passes
# 284  [direct_generation, cot_generation, dac_cot_ge...
# 285            [cot_generation, query_plan_generation]
# 286                            [query_plan_generation]
# 287                                                 []
# 288  [direct_generation, cot_generation, dac_cot_ge...

# %%
df['candidate_least_correct'].value_counts()
# Out:
# candidate_least_correct
# []                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            153
# [SELECT\n  COUNT(id)\nFROM appointment\nWHERE\n  MONTH(created_on) = 3 AND YEAR(created_on) = 2025, SELECT\n  COUNT(*) AS so_luong_lich_hen\nFROM appointment\nWHERE\n  YEAR(created_on) = 2025 AND MONTH(created_on) = 3, SELECT\n  COUNT(id)\nFROM appointment\nWHERE\n  YEAR(created_on) = 2025 AND MONTH(created_on) = 3, SELECT\n  COUNT(id) AS total_appointments\nFROM appointment\nWHERE\n  YEAR(appointment_time) = 2025 AND MONTH(appointment_time) = 3]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              1
# [SELECT\n  COUNT(DISTINCT T1.patient_id)\nFROM appointment AS T1\nINNER JOIN branch AS T2\n  ON T1.branch_id = T2.id\nWHERE\n  T2.branch_name = 'Chi nhánh Hà Đông', SELECT\n  COUNT(DISTINCT appointment.patient_id) AS SoLuongKhachHang\nFROM branch\nJOIN appointment\n  ON branch.id = appointment.branch_id\nWHERE\n  branch.branch_name = 'Chi nhánh Hà Đông', SELECT\n  COUNT(DISTINCT A.patient_id)\nFROM appointment AS A\nJOIN branch AS B\n  ON A.branch_id = B.id\nWHERE\n  B.branch_name = 'Chi nhánh Hà Đông', SELECT\n  COUNT(DISTINCT T1.patient_id)\nFROM appointment AS T1\nINNER JOIN branch AS T2\n  ON T1.branch_id = T2.id\nWHERE\n  T2.branch_name = 'Chi nhánh Hà Đông']                                                                                                                                                                                                                                                                                                                                                                1
# [SELECT\n  COUNT(id)\nFROM appointment\nWHERE\n  EXTRACT(YEAR FROM cancelled_on) = 2025 AND EXTRACT(MONTH FROM cancelled_on) = 3, SELECT\n  COUNT(id) AS `Số lượng lịch hẹn bị hủy trong tháng 3 năm 2025`\nFROM appointment\nWHERE\n  EXTRACT(YEAR_MONTH FROM cancelled_on) = 202503, SELECT\n  COUNT(A.id) AS so_luong_lich_hen_bi_huy\nFROM appointment AS A\nWHERE\n  A.cancelled_on BETWEEN '2025-03-01' AND '2025-03-31', SELECT\n  COUNT(id) AS num_cancelled_appointments\nFROM appointment\nWHERE\n  CAST(cancelled_on AS DATE) LIKE '2025-03-%']                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      1
# [SELECT DISTINCT\n  p.full_name\nFROM patient AS p\nJOIN appointment AS a\n  ON p.id = a.patient_id\nWHERE\n  DATE(a.appointment_time) = '2025-03-13', SELECT\n  p.full_name AS patient_name\nFROM appointment AS a\nINNER JOIN patient AS p\n  ON a.patient_id = p.id\nWHERE\n  DATE(a.appointment_time) = '2025-03-13', SELECT DISTINCT\n  p.full_name AS patient_name\nFROM patient AS p\nJOIN appointment AS a\n  ON p.id = a.patient_id\nWHERE\n  DATE(a.appointment_time) = '2025-03-13', SELECT DISTINCT\n  p.full_name AS patient_name\nFROM patient AS p\nJOIN appointment AS a\n  ON p.id = a.patient_id\nWHERE\n  DATE(a.appointment_time) = '2025-03-13']                                                                                                                                                                                                                                                                                                                                                                                           1
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              ...
# [SELECT\n  SUM(sale_invoice.total_amount) AS `Tổng doanh thu`\nFROM sale_invoice\nJOIN patient\n  ON sale_invoice.patient_id = patient.id\nWHERE\n  patient.full_name = 'Anh Thư', SELECT\n  SUM(si.total_amount) AS `Tổng doanh thu`\nFROM sale_invoice AS si\nJOIN patient AS p\n  ON si.patient_id = p.id\nWHERE\n  p.full_name = 'Anh Thư', SELECT\n  SUM(si.total_amount) AS total_revenue\nFROM sale_invoice AS si\nJOIN patient AS p\n  ON si.patient_id = p.id\nWHERE\n  p.full_name = 'Anh Thư']                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       1
# [SELECT\n  si.service_info_name,\n  COUNT(aps.service_info_id) AS total_usage\nFROM appointment_service AS aps\nJOIN service_info AS si\n  ON aps.service_info_id = si.id\nGROUP BY\n  si.service_info_name\nORDER BY\n  total_usage DESC\nLIMIT 5, SELECT\n  si.service_info_name AS `Tên dịch vụ`,\n  COUNT(asi.service_info_id) AS `Số lần sử dụng`\nFROM appointment_service AS asi\nJOIN service_info AS si\n  ON asi.service_info_id = si.id\nGROUP BY\n  asi.service_info_id\nORDER BY\n  COUNT(asi.service_info_id) DESC\nLIMIT 5, SELECT\n  si.service_info_name,\n  COUNT(aps.service_info_id) AS times_used\nFROM appointment_service AS aps\nJOIN service_info AS si\n  ON aps.service_info_id = si.id\nGROUP BY\n  si.service_info_name\nORDER BY\n  times_used DESC\nLIMIT 5, SELECT\n  si.service_info_name,\n  COUNT(aps.service_info_id) AS appointment_count\nFROM appointment_service AS aps\nJOIN service_info AS si\n  ON aps.service_info_id = si.id\nGROUP BY\n  si.service_info_name\nORDER BY\n  appointment_count DESC\nLIMIT 5]      1
# [SELECT\n  p.full_name AS patient_name,\n  COUNT(*) AS total_cancelled_appointments\nFROM appointment AS a\nJOIN patient AS p\n  ON a.patient_id = p.id\nWHERE\n  a.appointment_status_id = 20\nGROUP BY\n  p.id\nORDER BY\n  total_cancelled_appointments DESC\nLIMIT 1, SELECT\n  p.full_name AS patient_name,\n  COUNT(a.patient_id) AS number_of_cancelled_appointments\nFROM patient AS p\nJOIN appointment AS a\n  ON p.id = a.patient_id\nWHERE\n  a.appointment_status_id = 20\nGROUP BY\n  p.full_name\nORDER BY\n  number_of_cancelled_appointments DESC\nLIMIT 1]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    1
# [SELECT\n  e.first_name,\n  e.last_name,\n  COUNT(a.id) AS total_appointments\nFROM employee AS e\nJOIN appointment AS a\n  ON e.id = a.schedule_by\nGROUP BY\n  e.id\nORDER BY\n  total_appointments DESC]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     1
# [SELECT\n  b.branch_name,\n  COUNT(a.id) AS total_appointments\nFROM branch AS b\nJOIN appointment AS a\n  ON b.id = a.branch_id\nGROUP BY\n  b.branch_name\nORDER BY\n  total_appointments DESC\nLIMIT 1, SELECT\n  b.branch_name,\n  COUNT(*) AS appointment_count\nFROM branch AS b\nJOIN appointment AS a\n  ON b.id = a.branch_id\nGROUP BY\n  b.id\nORDER BY\n  appointment_count DESC\nLIMIT 1, SELECT\n  b.branch_name,\n  COUNT(a.id) AS total_appointments\nFROM branch AS b\nJOIN appointment AS a\n  ON b.id = a.branch_id\nGROUP BY\n  b.branch_name\nORDER BY\n  total_appointments DESC\nLIMIT 1, SELECT\n  b.branch_name,\n  COUNT(a.id) AS total_appointments\nFROM branch AS b\nJOIN appointment AS a\n  ON b.id = a.branch_id\nGROUP BY\n  b.branch_name\nORDER BY\n  total_appointments DESC\nLIMIT 1]                                                                                                                                                                                                                                      1
# Name: count, Length: 137, dtype: int64

# %%
df['llm_exact_match'].value_counts()
# Out:
# llm_exact_match
# True     127
# False     97
# Name: count, dtype: int64

# %%
df['llm_execution_match'].value_counts()
# Out:
# llm_execution_match
# True     135
# False     89
# Name: count, dtype: int64

# %%
candidate_counter = {}
for candidate in CANDIDATE_NAMES:
    candidate_counter[candidate] = df['candidate_passes'].apply(lambda x: candidate in x).sum()
candidate_counter
# df['candidate_passes']
# Out:
# {'direct_generation': np.int64(100),
#  'cot_generation': np.int64(109),
#  'dac_cot_genration': np.int64(104),
#  'query_plan_generation': np.int64(102)}
