# %%
import json


def calculate_llm_execution_match_score(file_path):
    # Read the JSON file
    with open(file_path, "r", encoding="utf-8") as f:
        data = json.load(f)

    # Get the detailed results
    detailed_results = data["detailed_results"]

    # Count total queries and successful matches
    total_queries = len(detailed_results)
    successful_llm_matches = sum(
        1 for result in detailed_results if result["metrics"]["llm_execution_match"]
    )

    successful_llm_result_matches = sum(
        1 for result in detailed_results if result["metrics"]["llm_exact_match"]
    )
    successful_exact_matches = sum(
        1 for result in detailed_results if result["metrics"]["exact_match"]
    )
    successful_execution_matches = sum(
        1 for result in detailed_results if result["metrics"]["execution_match"]
    )
    # Calculate the score
    llm_match_score = successful_llm_matches / total_queries
    llm_result_match_score = successful_llm_result_matches / total_queries
    exact_match_score = successful_exact_matches / total_queries
    execution_match_score = successful_execution_matches / total_queries

    print(f"Total queries: {total_queries}")
    print(f"Successful llm_execution_matches: {successful_llm_matches}")
    print(f"Successful llm_result_matches: {successful_llm_result_matches}")
    print(f"Successful exact_matches: {successful_exact_matches}")
    print(f"Successful execution_matches: {successful_execution_matches}")
    print(f"llm_match_score: {llm_match_score:.4f}")
    print(f"llm_result_match_score: {llm_result_match_score:.4f}")
    print(f"exact_match_score: {exact_match_score:.4f}")
    print(f"execution_match_score: {execution_match_score:.4f}")

# %%
import json

def find_missing_keys():
    # Read the JSON file
    with open('../LLM-as-judge-result.full.json', 'r', encoding='utf-8') as f:
        data = json.load(f)
    
    # Get the detailed results
    detailed_results = data['detailed_results']
    
    # Define the expected keys for each result entry
    expected_keys = {
        'question',
        'generated',
        'ground_truth',
        'ground_truth_result',
        'generated_result',
        'metrics'
    }
    
    # Define the expected keys for metrics
    expected_metric_keys = {
        'exact_match',
        'execution_match',
        'llm_exact_match',
        'llm_execution_match'
    }
    
    # Check each result entry
    for i, result in enumerate(detailed_results):
        # Check main keys
        missing_keys = expected_keys - set(result.keys())
        if missing_keys:
            print(f"\nEntry {i} is missing main keys: {missing_keys}")
        
        # Check metrics keys
        if 'metrics' in result:
            missing_metric_keys = expected_metric_keys - set(result['metrics'].keys())
            if missing_metric_keys:
                print(result)
                print(f"Entry {i} is missing metric keys: {missing_metric_keys}")
        else:
            print(result)
            print(f"Entry {i} is missing the entire metrics object")

if __name__ == "__main__":
    find_missing_keys()

# %%
# part01
calculate_llm_execution_match_score()
# Out:
# Total queries: 129
# Successful llm_execution_matches: 74
# Score: 0.5736

# %%
# part02
calculate_llm_execution_match_score('../results-LLM-judge.part02.json')
# Out:
# Total queries: 94
# Successful llm_execution_matches: 61
# Score: 0.6489

# %%
calculate_llm_execution_match_score('../LLM-as-judge-result.full.json')
# Out:
# Total queries: 223
# Successful llm_execution_matches: 135
# Successful llm_result_matches: 127
# Successful exact_matches: 1
# Successful execution_matches: 116
# llm_match_score: 0.6054
# llm_result_match_score: 0.5695
# exact_match_score: 0.0045
# execution_match_score: 0.5202

# %%
import pandas as pd
import json

def merge_csv_with_json():
    # Read the CSV file with proper encoding and quoting
    csv_path = '../data/GSV/generated-data/gen_success_data_results_LLM_judge.csv'
    df = pd.read_csv(csv_path, 
                     encoding='utf-8',
                     quoting=1,  # QUOTE_ALL mode
                     escapechar='\\',
                     on_bad_lines='warn')
    
    # Read the JSON file
    json_path = '../LLM-as-judge-result.full.json'
    with open(json_path, 'r', encoding='utf-8') as f:
        json_data = json.load(f)
    
    # Print first few entries from both sources for comparison
    print("First few entries from CSV:")
    for idx, row in df.head(2).iterrows():
        print(f"\nCSV Question: {repr(row['question'])}")
        print(f"CSV Ground Truth: {repr(row['ground_truth_sql'])}")
    
    print("\nFirst few entries from JSON:")
    for result in json_data['detailed_results'][:2]:
        print(f"\nJSON Question: {repr(result['question'])}")
        print(f"JSON Ground Truth: {repr(result['ground_truth'])}")
    
    # Create a dictionary from JSON data for easy lookup
    json_lookup = {}
    for result in json_data['detailed_results']:
        # Clean and normalize the text for comparison
        question = result['question'].strip()
        ground_truth = result['ground_truth'].strip()
        key = (question, ground_truth)
        json_lookup[key] = {
            'llm_exact_match': result['metrics']['llm_exact_match'],
            'llm_execution_match': result['metrics']['llm_execution_match']
        }
    
    # Add new columns to DataFrame
    df['llm_exact_match'] = None
    df['llm_execution_match'] = None
    
    # Match and fill values
    matched_count = 0
    for idx, row in df.iterrows():
        # Clean and normalize the text for comparison
        question = row['question'].strip()
        ground_truth = row['ground_truth_sql'].strip()
        key = (question, ground_truth)
        
        # Print the first few attempts at matching
        if idx < 2:
            print(f"\nTrying to match:")
            print(f"Question: {repr(question)}")
            print(f"Ground Truth: {repr(ground_truth)}")
            print(f"Available keys in json_lookup: {list(json_lookup.keys())[:2]}")
        
        if key in json_lookup:
            df.at[idx, 'llm_exact_match'] = json_lookup[key]['llm_exact_match']
            df.at[idx, 'llm_execution_match'] = json_lookup[key]['llm_execution_match']
            matched_count += 1
        else:
            print(f"Warning: No match found for question: {repr(question)}")
            print(f"Ground truth: {repr(ground_truth)}")
    
    # Save the updated CSV with proper encoding
    output_path = '../data/GSV/generated-data/gen_success_data_results_LLM_judge_updated.csv'
    df.to_csv(output_path, 
              index=False,
              encoding='utf-8',
              quoting=1,  # QUOTE_ALL mode
              escapechar='\\')
    
    # Print statistics
    print(f"\nProcessing complete:")
    print(f"Total records in CSV: {len(df)}")
    print(f"Successfully matched records: {matched_count}")
    print(f"Total llm_exact_matches: {sum(df[df['llm_exact_match'].notna()]['llm_exact_match'])}")
    print(f"Total llm_execution_matches: {sum(df[df['llm_execution_match'].notna()]['llm_execution_match'])}")

if __name__ == "__main__":
    merge_csv_with_json()
# Out:
# First few entries from CSV:
#
# CSV Question: 'Có bao nhiêu lịch hẹn được tạo trong tháng 3 năm 2025?\n'
# CSV Ground Truth: 'SELECT COUNT(*) FROM appointment WHERE YEAR(created_on) = 2025 AND MONTH(created_on) = 3;\n'
#
# CSV Question: 'Liệt kê tất cả các chi nhánh hiện đang hoạt động.\n'
# CSV Ground Truth: 'SELECT * FROM branch WHERE is_active = 1;\n'
#
# First few entries from JSON:
#
# JSON Question: 'Có bao nhiêu lịch hẹn được tạo trong tháng 3 năm 2025?\n'
# JSON Ground Truth: 'SELECT COUNT(*) FROM appointment WHERE YEAR(created_on) = 2025 AND MONTH(created_on) = 3;\n'
#
# JSON Question: 'Liệt kê tất cả các chi nhánh hiện đang hoạt động.\n'
# JSON Ground Truth: 'SELECT * FROM branch WHERE is_active = 1;\n'
#
# Trying to match:
# Question: 'Có bao nhiêu lịch hẹn được tạo trong tháng 3 năm 2025?'
# Ground Truth: 'SELECT COUNT(*) FROM appointment WHERE YEAR(created_on) = 2025 AND MONTH(created_on) = 3;'
# Available keys in json_lookup: [('Có bao nhiêu lịch hẹn được tạo trong tháng 3 năm 2025?', 'SELECT COUNT(*) FROM appointment WHERE YEAR(created_on) = 2025 AND MONTH(created_on) = 3;'), ('Liệt kê tất cả các chi nhánh hiện đang hoạt động.', 'SELECT * FROM branch WHERE is_active = 1;')]
#
# Trying to match:
# Question: 'Liệt kê tất cả các chi nhánh hiện đang hoạt động.'
# Ground Truth: 'SELECT * FROM branch WHERE is_active = 1;'
# Available keys in json_lookup: [('Có bao nhiêu lịch hẹn được tạo trong tháng 3 năm 2025?', 'SELECT COUNT(*) FROM appointment WHERE YEAR(created_on) = 2025 AND MONTH(created_on) = 3;'), ('Liệt kê tất cả các chi nhánh hiện đang hoạt động.', 'SELECT * FROM branch WHERE is_active = 1;')]
# Warning: No match found for question: 'Liệt kê tất cả các lịch hẹn có trạng thái "Đã xác nhận" (appointment_status_id = 16).'
# Ground truth: 'SELECT * FROM appointment WHERE appointment_status_id = 16;'
# Warning: No match found for question: 'Tìm tất cả các lịch hẹn của bệnh nhân có số điện thoại 0989149111.'
# Ground truth: "SELECT * FROM appointment WHERE mobile_phone = '0989149111';"
# Warning: No match found for question: 'Liệt kê các khiếu nại được tạo trong tháng 3 năm 2025.'
# Ground truth: 'SELECT * FROM complaint WHERE YEAR(created_on) = 2025 AND MONTH(created_on) = 3;'
# Warning: No match found for question: 'Liệt kê các phòng ban hiện có trong hệ thống.'
# Ground truth: 'SELECT * FROM department;'
# Warning: No match found for question: 'Liệt kê các lịch hẹn có thời gian ước tính là 30 phút.'
# Ground truth: 'SELECT * FROM appointment WHERE estimate_time = 30;'
# Warning: No match found for question: 'Tìm tất cả các lô hàng hết hạn trước ngày 01/01/2026.'
# Ground truth: "SELECT * FROM batch_info WHERE expiry_date < '2026-01-01';"
# Warning: No match found for question: 'Liệt kê các lịch hẹn có trạng thái lịch sử thay đổi trong tháng 3 năm 2025.'
# Ground truth: 'SELECT a.* FROM appointment a JOIN appointment_history ah ON a.id = ah.appointment_id WHERE YEAR(ah.created_on) = 2025 AND MONTH(ah.created_on) = 3;'
# Warning: No match found for question: 'Tìm tất cả các khiếu nại liên quan đến dịch vụ "Triệt lông ấn đường".'
# Ground truth: "SELECT * FROM complaint WHERE service_name = 'Triệt lông ấn đường';"
# Warning: No match found for question: 'Liệt kê các lô hàng có số lượng còn lại lớn hơn 0.'
# Ground truth: 'SELECT * FROM batch_info WHERE remain_quantity > 0;'
# Warning: No match found for question: 'Liệt kê các lịch hẹn có kỹ thuật viên thực hiện (technican_id không null).'
# Ground truth: 'SELECT * FROM appointment WHERE technican_id IS NOT NULL;'
# Warning: No match found for question: 'Liệt kê các lịch hẹn có nội dung (content) không rỗng.'
# Ground truth: "SELECT * FROM appointment WHERE content IS NOT NULL AND content != '';"
# Warning: No match found for question: 'Liệt kê các lịch hẹn có thời gian ước tính lớn hơn 30 phút.'
# Ground truth: 'SELECT * FROM appointment WHERE estimate_time > 30;'
# Warning: No match found for question: 'Tìm tất cả các lịch hẹn của bệnh nhân có id = 8946.'
# Ground truth: 'SELECT * FROM appointment WHERE patient_id = 8946;'
# Warning: No match found for question: 'Liệt kê các lô hàng có trạng thái hết hạn (expiry_status_id = 123).'
# Ground truth: 'SELECT * FROM batch_info WHERE expiry_status_id = 123;'
# Warning: No match found for question: 'Liệt kê các khiếu nại có trạng thái "Đã giải quyết" (complaint_status_id = 35).'
# Ground truth: 'SELECT * FROM complaint WHERE complaint_status_id = 35;'
# Warning: No match found for question: 'Tìm tên bệnh nhân và số điện thoại của các lịch hẹn có trạng thái "Đã xác nhận".'
# Ground truth: 'SELECT full_name, mobile_phone FROM appointment WHERE appointment_status_id = 16;'
# Warning: No match found for question: 'Liệt kê các lịch hẹn có thời gian thực hiện trong tháng 3 năm 2025.'
# Ground truth: 'SELECT * FROM appointment WHERE YEAR(appointment_time) = 2025 AND MONTH(appointment_time) = 3;'
# Warning: No match found for question: 'Tìm danh sách bệnh nhân có lịch hẹn tại chi nhánh Cầu Giấy và đã thanh toán hóa đơn dịch vụ.'
# Ground truth: "SELECT DISTINCT p.full_name \nFROM patient p \nJOIN appointment a ON p.id = a.patient_id \nJOIN service_invoice si ON p.id = si.patient_id \nWHERE a.branch_id = (SELECT id FROM branch WHERE branch_name = 'Chi nhánh Cầu Giấy') \nAND si.bill_status_id = 54;"
# Warning: No match found for question: 'Tìm danh sách các bệnh nhân có lịch hẹn tại chi nhánh Cầu Giấy và có tổng số tiền hóa đơn thuốc lớn hơn 0.'
# Ground truth: "SELECT DISTINCT p.full_name \nFROM patient p \nJOIN appointment a ON p.id = a.patient_id \nJOIN sale_invoice si ON p.id = si.patient_id \nJOIN store st ON si.store_id = st.id \nWHERE a.branch_id = (SELECT id FROM branch WHERE branch_name = 'Chi nhánh Cầu Giấy') \nAND si.total_amount > 0 \nAND si.bill_status_id != 56;"
# Warning: No match found for question: 'Tìm danh sách các bệnh nhân có lịch hẹn tại chi nhánh Hà Đông và có tổng số tiền cọc lớn hơn 0.'
# Ground truth: "SELECT DISTINCT p.full_name \nFROM patient p \nJOIN appointment a ON p.id = a.patient_id \nJOIN service_invoice si ON p.id = si.patient_id \nWHERE a.branch_id = (SELECT id FROM branch WHERE branch_name = 'Chi nhánh Hà Đông') \nAND si.deposit_amount > 0 \nAND si.bill_status_id != 56;"
# Warning: No match found for question: 'Liệt kê tất cả các bệnh nhân nữ.'
# Ground truth: 'SELECT * FROM patient WHERE sex = 0;'
# Warning: No match found for question: 'Lấy thông tin các lịch hẹn được tạo bởi người dùng có ID là 1.'
# Ground truth: 'SELECT * FROM appointment WHERE created_by = 1;'
# Warning: No match found for question: 'Cho biết tên đầy đủ và số điện thoại của các bệnh nhân có trong bảng lịch hẹn.'
# Ground truth: 'SELECT full_name, mobile_phone FROM appointment;'
# Warning: No match found for question: 'Liệt kê các lịch hẹn tại chi nhánh có ID là 1.'
# Ground truth: 'SELECT * FROM appointment WHERE branch_id = 1;'
# Warning: No match found for question: 'Những lịch hẹn nào có thời gian dự kiến lớn hơn 30 phút?'
# Ground truth: 'SELECT * FROM appointment WHERE estimate_time > 30;'
# Warning: No match found for question: 'Cho biết thông tin các lịch hẹn được tạo trong tháng 3 năm 2025.'
# Ground truth: 'SELECT * FROM appointment WHERE MONTH(created_on) = 3 AND YEAR(created_on) = 2025;'
# Warning: No match found for question: "Liệt kê các bệnh nhân có tên là 'Cường nguyễn' trong bảng lịch hẹn."
# Ground truth: "SELECT * FROM appointment WHERE full_name = 'Cường nguyễn';"
# Warning: No match found for question: "Liệt kê các lịch hẹn của bệnh nhân có số điện thoại '0989149111'."
# Ground truth: "SELECT * FROM appointment WHERE mobile_phone = '0989149111';"
# Warning: No match found for question: 'Liệt kê các lịch hẹn và tên bệnh nhân, sắp xếp theo thời gian hẹn gần nhất.'
# Ground truth: 'SELECT appointment_code, full_name, appointment_time FROM appointment ORDER BY appointment_time DESC;'
# Warning: No match found for question: 'Liệt kê các lịch hẹn chưa có bác sĩ phụ trách.'
# Ground truth: 'SELECT * FROM appointment WHERE doctor_id IS NULL;'
# Warning: No match found for question: "Liệt kê các lịch hẹn có người thực hiện tên là 'Admin' và số điện thoại người thực hiện là rỗng hoặc null."
# Ground truth: "SELECT * FROM appointment WHERE performer_name = 'Admin' AND (performer_phone IS NULL OR performer_phone = '');"
# Warning: No match found for question: 'Hiển thị 5 bệnh nhân mới nhất được thêm vào hệ thống. (Giả sử patient có created_on)'
# Ground truth: 'SELECT * FROM patient ORDER BY created_on DESC LIMIT 5;'
# Warning: No match found for question: 'Liệt kê các lịch hẹn được tạo trong quý 1 năm 2025.'
# Ground truth: "SELECT * FROM appointment WHERE created_on >= '2025-01-01 00:00:00' AND created_on < '2025-04-01 00:00:00';"
# Warning: No match found for question: 'Liệt kê các lịch hẹn được thực hiện bởi kỹ thuật viên có ID 38 tại chi nhánh ID 1.'
# Ground truth: 'SELECT * FROM appointment WHERE technican_id = 38 AND branch_id = 1;'
# Warning: No match found for question: "Liệt kê các lịch hẹn mà tên bệnh nhân bắt đầu bằng chữ 'V'."
# Ground truth: "SELECT * FROM appointment WHERE full_name LIKE 'V%';"
# Warning: No match found for question: 'Tìm các lịch hẹn có thời gian ước tính từ 30 đến 60 phút.'
# Ground truth: 'SELECT * FROM appointment WHERE estimate_time BETWEEN 30 AND 60;'
# Warning: No match found for question: 'Liệt kê các lịch hẹn có cùng ngày tạo (created_on) nhưng khác người tạo (creator).'
# Ground truth: 'SELECT a1.* FROM appointment a1 JOIN appointment a2 ON DATE(a1.created_on) = DATE(a2.created_on) AND a1.creator != a2.creator AND a1.id != a2.id;'
# Warning: No match found for question: 'Các lịch hẹn nào được tạo trong giờ hành chính (8AM - 5PM)?'
# Ground truth: 'SELECT * FROM appointment WHERE HOUR(created_on) >= 8 AND HOUR(created_on) < 17;'
# Warning: No match found for question: "Liệt kê các lịch hẹn của bệnh nhân nữ được tạo bởi 'Admin'."
# Ground truth: "SELECT * FROM appointment WHERE sex = 0 AND creator = 'Admin';"
# Warning: No match found for question: 'Danh sách các dịch vụ chưa từng được sử dụng.'
# Ground truth: 'SELECT s.service_name FROM service s LEFT JOIN appointment_service aps ON s.id = aps.service_id WHERE aps.id IS NULL;'
# Warning: No match found for question: "Tìm các lịch hẹn mà tên bệnh nhân chứa từ 'Kim'."
# Ground truth: "SELECT * FROM appointment WHERE full_name LIKE '%Kim%';"
# Warning: No match found for question: 'Tìm các cặp bệnh nhân đã từng có lịch hẹn với cùng một bác sĩ vào cùng một ngày.'
# Ground truth: 'SELECT DISTINCT a1.full_name AS patient1_name, a2.full_name AS patient2_name, a1.doctor_id, DATE(a1.appointment_time) FROM appointment a1 JOIN appointment a2 ON a1.doctor_id = a2.doctor_id AND DATE(a1.appointment_time) = DATE(a2.appointment_time) AND a1.patient_id < a2.patient_id;'
# Warning: No match found for question: 'Liệt kê các lịch hẹn được tạo vào cuối tuần (Thứ 7 hoặc Chủ Nhật).'
# Ground truth: 'SELECT * FROM appointment WHERE DAYOFWEEK(created_on) IN (1, 7);'
# Warning: No match found for question: 'Liệt kê các lịch hẹn có thời gian ước tính (estimate_time) chính xác là 60 phút.'
# Ground truth: 'SELECT * FROM appointment WHERE estimate_time = 60;'
# Warning: No match found for question: "Cho biết tên các bệnh nhân có lịch hẹn được tạo bởi 'Admin' và thực hiện bởi 'Admin'."
# Ground truth: "SELECT full_name FROM appointment WHERE creator = 'Admin' AND performer_name = 'Admin';"
# Warning: No match found for question: 'Liệt kê các lịch hẹn trong tháng 4 năm 2025.'
# Ground truth: 'SELECT * FROM appointment WHERE MONTH(appointment_time) = 4 AND YEAR(appointment_time) = 2025;'
# Warning: No match found for question: 'Liệt kê các lịch hẹn có cùng bệnh nhân và cùng bác sĩ.'
# Ground truth: 'SELECT patient_id, doctor_id, GROUP_CONCAT(appointment_code) FROM appointment WHERE patient_id IS NOT NULL AND doctor_id IS NOT NULL GROUP BY patient_id, doctor_id HAVING COUNT(*) > 1;'
# Warning: No match found for question: 'Tìm các lịch hẹn mà thời gian tạo (created_on) và thời gian hẹn (appointment_time) là cùng một ngày.'
# Ground truth: 'SELECT * FROM appointment WHERE DATE(created_on) = DATE(appointment_time);'
# Warning: No match found for question: 'Liệt kê tên bệnh nhân và thời gian chờ trung bình của họ (từ lúc tạo lịch đến lúc hẹn).'
# Ground truth: 'SELECT full_name, AVG(TIMESTAMPDIFF(MINUTE, created_on, appointment_time)) AS avg_wait_minutes FROM appointment GROUP BY full_name, patient_id;'
# Warning: No match found for question: 'Liệt kê các lịch hẹn chưa được gán cho bất kỳ telesale nào.'
# Ground truth: 'SELECT * FROM appointment WHERE telesale_id IS NULL;'
# Warning: No match found for question: "Liệt kê các lịch hẹn có tên bệnh nhân chứa 'Thị' và được tạo trong năm 2025."
# Ground truth: "SELECT * FROM appointment WHERE full_name LIKE '%Thị%' AND YEAR(created_on) = 2025;"
# Warning: No match found for question: 'Tìm các lịch hẹn mà tên người thực hiện (performer_name) và người tạo (creator) là giống nhau.'
# Ground truth: 'SELECT * FROM appointment WHERE performer_name = creator;'
# Warning: No match found for question: "Tìm các lịch hẹn có mã bắt đầu bằng 'AP8946'."
# Ground truth: "SELECT * FROM appointment WHERE appointment_code LIKE 'AP8946%';"
# Warning: No match found for question: 'Tìm các lịch hẹn có ngày tạo là ngày đầu tiên của tháng.'
# Ground truth: 'SELECT * FROM appointment WHERE DAY(created_on) = 1;'
# Warning: No match found for question: "Liệt kê các lịch hẹn được tạo bởi người có tên 'Vttech' hoặc 'Admin'."
# Ground truth: "SELECT * FROM appointment WHERE creator = 'Vttech' OR creator = 'Admin';"
# Warning: No match found for question: "Tìm các bệnh nhân có số điện thoại chứa '666'."
# Ground truth: "SELECT DISTINCT full_name, mobile_phone FROM appointment WHERE mobile_phone LIKE '%666%';"
# Warning: No match found for question: 'Liệt kê các lịch hẹn có ngày tạo và ngày hẹn cách nhau hơn 7 ngày.'
# Ground truth: 'SELECT * FROM appointment WHERE DATEDIFF(appointment_time, created_on) > 7;'
# Warning: No match found for question: 'Tìm tên bệnh nhân và mã lịch hẹn cho các lịch hẹn được tạo bởi người dùng có ID 1 và thực hiện bởi nhân viên có ID 1.'
# Ground truth: 'SELECT full_name, appointment_code FROM appointment WHERE created_by = 1 AND schedule_by = 1;'
# Warning: No match found for question: 'Liệt kê các lịch hẹn không có dịch vụ nào được đính kèm.'
# Ground truth: 'SELECT a.* FROM appointment a LEFT JOIN appointment_service aps ON a.id = aps.appointment_id WHERE aps.id IS NULL;'
# Warning: No match found for question: 'Liệt kê các lịch hẹn có cùng tên bệnh nhân, cùng ngày hẹn nhưng khác bác sĩ.'
# Ground truth: 'SELECT a1.full_name, DATE(a1.appointment_time), a1.doctor_id, a2.doctor_id FROM appointment a1 JOIN appointment a2 ON a1.full_name = a2.full_name AND DATE(a1.appointment_time) = DATE(a2.appointment_time) AND a1.doctor_id != a2.doctor_id AND a1.id < a2.id;'
# Warning: No match found for question: "Liệt kê các lịch hẹn mà tên người tạo (creator) là 'Admin' và tên bệnh nhân là 'Cường nguyễn'."
# Ground truth: "SELECT * FROM appointment WHERE creator = 'Admin' AND full_name = 'Cường nguyễn';"
# Warning: No match found for question: 'Liệt kê tất cả các bệnh nhân nam?'
# Ground truth: 'SELECT * FROM patient WHERE patient.sex = 1;'
# Warning: No match found for question: "Tìm các lịch hẹn được thực hiện bởi nhân viên có tên 'Admin'?"
# Ground truth: "SELECT * FROM appointment WHERE performer_name = 'Admin';"
# Warning: No match found for question: 'Liệt kê các bệnh nhân đã thực hiện dịch vụ "Triệt lông ấn đường" và ngày thực hiện?'
# Ground truth: "SELECT p.full_name, td.action_date FROM patient p JOIN package pkg ON p.id = pkg.patient_id JOIN service s ON pkg.id = s.package_id JOIN treatment t ON s.id = t.service_id JOIN treatment_detail td ON t.id = td.treatment_id JOIN treatment_info ti ON t.treatment_info_id = ti.id WHERE ti.treatment_info_name LIKE '%Triệt lông ấn đường%';"
# Warning: No match found for question: 'Liệt kê các nhân viên và số lượng lịch hẹn họ đã tạo, sắp xếp giảm dần theo số lượng lịch hẹn?'
# Ground truth: 'SELECT e.first_name, e.last_name, COUNT(a.id) AS so_luong_lich_hen FROM employee e JOIN appointment a ON e.id = a.created_by GROUP BY e.id ORDER BY so_luong_lich_hen DESC;'
#
# Processing complete:
# Total records in CSV: 289
# Successfully matched records: 224
# Total llm_exact_matches: 127
# Total llm_execution_matches: 135

# %%
import pandas as pd

def calculate_metrics_by_level():
    # Read the updated CSV file
    csv_path = '../data/GSV/generated-data/gen_success_data_results_LLM_judge_updated.csv'
    df = pd.read_csv(csv_path, 
                     encoding='utf-8',
                     quoting=1,  # QUOTE_ALL mode
                     escapechar='\\',
                     on_bad_lines='warn')
    
    # print(df[df['llm_exact_match'].isna()])
    # return 
    # Filter rows that have both llm_exact_match and llm_execution_match values
    # (not missing, regardless of whether they are True or False)
    validated_df = df[df['llm_exact_match'].notna() & df['llm_execution_match'].notna()]
    
    # Group by level and calculate metrics
    level_metrics = {}
    for level in validated_df['level'].unique():
        level_data = validated_df[validated_df['level'] == level]
        total = len(level_data)
        exact_matches = sum(level_data['llm_exact_match'])
        execution_matches = sum(level_data['llm_execution_match'])
        
        level_metrics[level] = {
            'total_questions': total,
            'exact_matches': exact_matches,
            'execution_matches': execution_matches,
            'exact_match_score': exact_matches / total,
            'execution_match_score': execution_matches / total
        }
    
    # Print results
    print("Metrics by difficulty level (for questions with LLM metrics):")
    print("-" * 80)
    for level, metrics in level_metrics.items():
        print(f"\nLevel: {level}")
        print(f"Total questions: {metrics['total_questions']}")
        print(f"Exact matches: {metrics['exact_matches']} ({metrics['exact_match_score']*100:.2f}%)")
        print(f"Execution matches: {metrics['execution_matches']} ({metrics['execution_match_score']*100:.2f}%)")
    
    # Print overall statistics
    total_validated = len(validated_df)
    total_exact = sum(validated_df['llm_exact_match'])
    total_execution = sum(validated_df['llm_execution_match'])
    
    print("\nOverall statistics:")
    print(f"Total questions with LLM metrics: {total_validated}")
    print(f"Overall exact match score: {(total_exact/total_validated)*100:.2f}%")
    print(f"Overall execution match score: {(total_execution/total_validated)*100:.2f}%")

if __name__ == "__main__":
    calculate_metrics_by_level()
# Out:
# Metrics by difficulty level (for questions with LLM metrics):
# --------------------------------------------------------------------------------
#
# Level: easy
# Total questions: 77
# Exact matches: 59 (76.62%)
# Execution matches: 62 (80.52%)
#
# Level: hard
# Total questions: 147
# Exact matches: 68 (46.26%)
# Execution matches: 73 (49.66%)
#
# Overall statistics:
# Total questions with LLM metrics: 224
# Overall exact match score: 56.70%
# Overall execution match score: 60.27%
